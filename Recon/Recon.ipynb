# %% [markdown]
# # Recon

# %% [markdown]
# `Richard Rivaldo 13519185`
#
# `Informatics Engineering Institut Teknologi Bandung`

# %% [markdown]
# **Recon** is a `Text Recognition` project on building a `Deep Learning` model of recognizing texts containing alphabets in a picture. Without using the infamous `Tesseract`, this project will try to apply and use `Convolutional Recurrent Neural Network` which combines both CNN and RNN in its pipeline. I also plan to use `CTC Loss` and `Attention Model` in the project. This is actually my first project in `Computer Vision`, let's see how it goes!

# %% [markdown]
# The repository of the project: [Recon](https://github.com/RichardRivaldo/Recon). The dataset used in this project can also be found in the repository.

# %% [markdown]
# # Preparations

# %% [markdown]
# **Libraries**

# %%
import os
import cv2
import numpy as np
import tensorflow as tf
from pathlib import Path
from PIL import Image as im
from google.colab import drive
import matplotlib.pyplot as plt
from tensorflow.keras import Sequential
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from nltk.metrics.distance import edit_distance
from scipy.ndimage import interpolation as inter
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Dense, LSTM, BatchNormalization, Input, Conv2D, MaxPool2D, Lambda, Bidirectional, Layer

# %% [markdown]
# **Mount Drive**

# %%
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Path to Images Data**

# %%
# %rm -rf images
# !unzip "/content/drive/MyDrive/GaIB/Recon/images.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: images/95_Banes_5758.jpg
#   inflating: images/94_Undisclosed_82317.jpg
#   inflating: images/93_Affiliating_1411.jpg
#   inflating: images/92_COEQUALS_14685.jpg
#   inflating: images/91_Shadowier_69823.jpg
#   inflating: images/90_acquired_811.jpg
#   inflating: images/89_snoopier_72273.jpg
#   inflating: images/88_HUGHES_37216.jpg
#   inflating: images/87_Depopulates_20746.jpg
#   inflating: images/86_REVIEWS_65747.jpg
#   inflating: images/85_Craniums_17804.jpg
#   inflating: images/84_MISCONCEIVED_48832.jpg
#   inflating: images/83_philately_57195.jpg
#   inflating: images/82_Bullfrogs_10133.jpg
#   inflating: images/81_dengue_20578.jpg
#   inflating: images/80_preregistering_59794.jpg
#   inflating: images/79_FOUNDER_30506.jpg
#   inflating: images/78_millimeters_48468.jpg
#   inflating: images/77_endear_25654.jpg
#   inflating: images/76_MAHDI_46074.jpg
#   inflating: images/75_BULLETINS_10119.jpg
#   inflating: images/74_quintessentially_61910.jpg
#   inflating: images/73_PENITENTS_56426.jpg
#   inflating: images/72_Submit_75629.jpg
#   inflating: images/71_Dejesus_20222.jpg
#   inflating: images/70_HAIRSTYLE_34570.jpg
#   inflating: images/69_shearer_70033.jpg
#   inflating: images/68_IRAQI_40758.jpg
#   inflating: images/67_BROOMS_9784.jpg
#   inflating: images/66_tibetans_78986.jpg
#   inflating: images/65_stirrups_74788.jpg
#   inflating: images/64_overheard_54518.jpg
#   inflating: images/63_UNBINDING_81798.jpg
#   inflating: images/62_MEAGAN_47382.jpg
#   inflating: images/61_CIRCUMCISES_13738.jpg
#   inflating: images/60_BRIEFCASE_9535.jpg
#   inflating: images/59_terraced_78279.jpg
#   inflating: images/58_CASTLED_11901.jpg
#   inflating: images/57_Mishitting_48932.jpg
#   inflating: images/56_Catsuits_12083.jpg
#   inflating: images/55_divert_22891.jpg
#   inflating: images/54_Mcletchie_47360.jpg
#   inflating: images/53_PHOTOCOPY_57313.jpg
#   inflating: images/52_cannibalized_11188.jpg
#   inflating: images/51_chimed_13222.jpg
#   inflating: images/50_UNHARNESSING_82583.jpg
#   inflating: images/49_criminalizes_18089.jpg
#   inflating: images/48_LAPEL_43363.jpg
#   inflating: images/47_DEMIGODS_20422.jpg
#   inflating: images/46_Adjectivally_1038.jpg
#   inflating: images/45_REDEEMERS_63496.jpg
#   inflating: images/44_Munificently_50427.jpg
#   inflating: images/43_Snowboards_72331.jpg
#   inflating: images/42_premiered_59694.jpg
#   inflating: images/41_Sophistic_72788.jpg
#   inflating: images/40_Spoken_73609.jpg
#   inflating: images/39_VIABILITY_84489.jpg
#   inflating: images/38_Harked_35007.jpg
#   inflating: images/37_Kirby_42590.jpg
#   inflating: images/36_Legerdemain_43944.jpg
#   inflating: images/35_STOCKADE_74799.jpg
#   inflating: images/34_Krona_42931.jpg
#   inflating: images/33_hairsplitting_34565.jpg
#   inflating: images/32_Emancipate_25207.jpg
#   inflating: images/31_Lovelies_45401.jpg
#   inflating: images/30_casings_11849.jpg
#   inflating: images/29_Pilothouse_57647.jpg
#   inflating: images/28_gits_32575.jpg
#   inflating: images/27_Looses_45248.jpg
#   inflating: images/26_Andalusian_2748.jpg
#   inflating: images/25_lionize_44688.jpg
#   inflating: images/24_Floaters_29614.jpg
#   inflating: images/23_RAPIST_62448.jpg
#   inflating: images/22_Fyi_31438.jpg
#   inflating: images/21_CHAMPAGNES_12601.jpg
#   inflating: images/20_showdowns_70506.jpg
#   inflating: images/19_INDECOROUS_38940.jpg
#   inflating: images/18_mutability_50601.jpg
#   inflating: images/17_JANGLER_41219.jpg
#   inflating: images/16_padlocks_54979.jpg
#   inflating: images/15_croon_18229.jpg
#   inflating: images/14_chooses_13414.jpg
#   inflating: images/13_SUMMERHOUSE_76039.jpg
#   inflating: images/12_Shame_69890.jpg
#   inflating: images/11_Chinwag_13265.jpg
#   inflating: images/10_sudden_75862.jpg
#   inflating: images/9_BYWORD_10616.jpg
#   inflating: images/8_POLYMERIC_58696.jpg
#   inflating: images/7_REDACTING_63459.jpg
#   inflating: images/6_MOLAR_49379.jpg
#   inflating: images/5_Pollock_58642.jpg
#   inflating: images/4_rhomboid_65942.jpg
#   inflating: images/3_gadders_31474.jpg
#   inflating: images/2_Malnutrition_46313.jpg
#   inflating: images/1_OFFICIOUS_53152.jpg
#   inflating: images/501_Unplugging_82978.jpg
#   inflating: images/500_FEUDAL_28674.jpg
#   inflating: images/499_gaudiest_31912.jpg
#   inflating: images/498_Identity_37818.jpg
#   inflating: images/497_Merrymaking_47913.jpg
#   inflating: images/496_PEDANTS_56220.jpg
#   inflating: images/495_madmen_45953.jpg
#   inflating: images/494_UNDERBID_82080.jpg
#   inflating: images/493_Sidebar_70743.jpg
#   inflating: images/492_REWORKS_65865.jpg
#   inflating: images/491_AIRDROME_1732.jpg
#   inflating: images/490_assignors_4419.jpg
#   inflating: images/489_Goodnight_33122.jpg
#   inflating: images/488_Smoothing_72056.jpg
#   inflating: images/487_SODA_72486.jpg
#   inflating: images/486_SKITTISHNESS_71368.jpg
#   inflating: images/485_BRAVADO_9278.jpg
#   inflating: images/484_underhand_82148.jpg
#   inflating: images/483_Onstage_53416.jpg
#   inflating: images/482_INCOMMODING_38787.jpg
#   inflating: images/481_beth_7213.jpg
#   inflating: images/480_moonshots_49736.jpg
#   inflating: images/479_crawling_17876.jpg
#   inflating: images/478_declaimers_19753.jpg
#   inflating: images/477_transfixes_80205.jpg
#   inflating: images/476_WYCHERLEY_87508.jpg
#   inflating: images/475_Swarthy_76675.jpg
#   inflating: images/474_STRAIGHTFORWARDLY_75030.jpg
#   inflating: images/473_PLAINT_58000.jpg
#   inflating: images/472_SHELLACKING_70102.jpg
#   inflating: images/471_LIFESPANS_44409.jpg
#   inflating: images/470_epidermis_26199.jpg
#   inflating: images/469_CHAMBERS_12592.jpg
#   inflating: images/468_Cafeterias_10744.jpg
#   inflating: images/467_DECAMPMENT_19633.jpg
#   inflating: images/466_GELLING_32048.jpg
#   inflating: images/465_Forbidding_30123.jpg
#   inflating: images/464_speculate_73252.jpg
#   inflating: images/463_HALFPENNY_34609.jpg
#   inflating: images/462_Railroading_62227.jpg
#   inflating: images/461_tomas_79530.jpg
#   inflating: images/460_unsuitably_83297.jpg
#   inflating: images/459_earwigs_24421.jpg
#   inflating: images/458_SMASHED_71949.jpg
#   inflating: images/457_Modernly_49289.jpg
#   inflating: images/456_oxides_54861.jpg
#   inflating: images/455_GENTLED_32159.jpg
#   inflating: images/454_SUPPORTS_76365.jpg
#   inflating: images/453_GUNFIRE_34242.jpg
#   inflating: images/452_maladroitness_46217.jpg
#   inflating: images/451_deciding_19714.jpg
#   inflating: images/450_DINETTES_21737.jpg
#   inflating: images/449_Macniven_45900.jpg
#   inflating: images/448_Acts_888.jpg
#   inflating: images/447_slurry_71895.jpg
#   inflating: images/446_AE_1325.jpg
#   inflating: images/445_Chillingly_13215.jpg
#   inflating: images/444_Adherence_1016.jpg
#   inflating: images/443_backwash_5431.jpg
#   inflating: images/442_hypnotizes_37654.jpg
#   inflating: images/441_blindsiding_8042.jpg
#   inflating: images/440_Maoist_46625.jpg
#   inflating: images/439_closing_14314.jpg
#   inflating: images/438_Gospels_33213.jpg
#   inflating: images/437_Elitists_25091.jpg
#   inflating: images/436_bsd_9911.jpg
#   inflating: images/435_receivables_63073.jpg
#   inflating: images/434_Droopiest_23867.jpg
#   inflating: images/433_HUSSERL_37467.jpg
#   inflating: images/432_ILLUMINES_37979.jpg
#   inflating: images/431_AMBLERS_2404.jpg
#   inflating: images/430_Evangelina_26827.jpg
#   inflating: images/429_Difficult_21574.jpg
#   inflating: images/428_exoskeletons_27308.jpg
#   inflating: images/427_birthrate_7665.jpg
#   inflating: images/426_OGLER_53188.jpg
#   inflating: images/425_Files_28866.jpg
#   inflating: images/424_MANFRED_46443.jpg
#   inflating: images/423_ufos_81578.jpg
#   inflating: images/422_Bavaria_6314.jpg
#   inflating: images/421_CANONIZES_11223.jpg
#   inflating: images/420_Carrel_11711.jpg
#   inflating: images/419_LOUISIANAN_45355.jpg
#   inflating: images/418_imprecisely_38452.jpg
#   inflating: images/417_resitting_65196.jpg
#   inflating: images/416_shinny_70240.jpg
#   inflating: images/415_pierced_57522.jpg
#   inflating: images/414_Pazzo_56088.jpg
#   inflating: images/413_REPACKAGING_64719.jpg
#   inflating: images/412_robots_66402.jpg
#   inflating: images/411_Orrises_53811.jpg
#   inflating: images/410_ADELINE_997.jpg
#   inflating: images/409_Lugging_45568.jpg
#   inflating: images/408_Clorets_14295.jpg
#   inflating: images/407_JOBLINE_41610.jpg
#   inflating: images/406_INSTIGATORS_39923.jpg
#   inflating: images/405_murders_50455.jpg
#   inflating: images/404_Bookplate_8750.jpg
#   inflating: images/403_DECENTRALIZING_19699.jpg
#   inflating: images/402_Homebody_36555.jpg
#   inflating: images/401_MUGGER_50246.jpg
#   inflating: images/400_Proposes_60664.jpg
#   inflating: images/399_MALACHITE_46210.jpg
#   inflating: images/398_PIANISSIMOS_57416.jpg
#   inflating: images/397_Remark_64460.jpg
#   inflating: images/396_Mugabe_50242.jpg
#   inflating: images/395_minnesotan_48662.jpg
#   inflating: images/394_EFFRONTERY_24753.jpg
#   inflating: images/393_Fondue_30007.jpg
#   inflating: images/392_entrenching_26076.jpg
#   inflating: images/391_mohacs_49332.jpg
#   inflating: images/390_Kinder_42512.jpg
#   inflating: images/389_OBJECTIVE_52784.jpg
#   inflating: images/388_DANDIFY_19167.jpg
#   inflating: images/387_happier_34911.jpg
#   inflating: images/386_coccyges_14569.jpg
#   inflating: images/385_alteration_2263.jpg
#   inflating: images/384_rattly_62603.jpg
#   inflating: images/383_annexations_2956.jpg
#   inflating: images/382_townswoman_79948.jpg
#   inflating: images/381_dittoing_22852.jpg
#   inflating: images/380_Equivocal_26323.jpg
#   inflating: images/379_nitrates_51758.jpg
#   inflating: images/378_tubbiest_81039.jpg
#   inflating: images/377_DARTERS_19283.jpg
#   inflating: images/376_Reacquaints_62703.jpg
#   inflating: images/375_Recorder_63349.jpg
#   inflating: images/374_dec_19609.jpg
#   inflating: images/373_clowns_14370.jpg
#   inflating: images/372_Thoughtless_78758.jpg
#   inflating: images/371_Pearson_56152.jpg
#   inflating: images/370_wozniak_87340.jpg
#   inflating: images/369_TILED_79097.jpg
#   inflating: images/368_INTERRUPTIONS_40367.jpg
#   inflating: images/367_Wimples_86658.jpg
#   inflating: images/366_BAROMETERS_6022.jpg
#   inflating: images/365_mingo_48591.jpg
#   inflating: images/364_DISESTABLISHED_22255.jpg
#   inflating: images/363_mariana_46730.jpg
#   inflating: images/362_Flouters_29728.jpg
#   inflating: images/361_Worcesters_87178.jpg
#   inflating: images/360_trawls_80435.jpg
#   inflating: images/359_Decamps_19634.jpg
#   inflating: images/358_Scarf_68167.jpg
#   inflating: images/357_REALITIES_62793.jpg
#   inflating: images/356_aprons_3659.jpg
#   inflating: images/355_INNOCENT_39660.jpg
#   inflating: images/354_redeveloped_63528.jpg
#   inflating: images/353_Forestland_30273.jpg
#   inflating: images/352_pesetas_56964.jpg
#   inflating: images/351_Wrings_87428.jpg
#   inflating: images/350_underlings_82161.jpg
#   inflating: images/349_salivating_67494.jpg
#   inflating: images/348_transformations_80210.jpg
#   inflating: images/347_ENG_25767.jpg
#   inflating: images/346_rizal_66310.jpg
#   inflating: images/345_blondest_8136.jpg
#   inflating: images/344_teleconferences_77948.jpg
#   inflating: images/343_Queuing_61836.jpg
#   inflating: images/342_NAZISMS_51076.jpg
#   inflating: images/341_KLUGES_42675.jpg
#   inflating: images/340_Discussion_22201.jpg
#   inflating: images/339_DEVASTATORS_21250.jpg
#   inflating: images/338_Stumps_75413.jpg
#   inflating: images/337_chatter_12877.jpg
#   inflating: images/336_TAEJON_77206.jpg
#   inflating: images/335_squealing_73955.jpg
#   inflating: images/334_demoniacally_20496.jpg
#   inflating: images/333_CRAFTS_17768.jpg
#   inflating: images/332_FRAILEST_30607.jpg
#   inflating: images/331_FRIEZE_30910.jpg
#   inflating: images/330_recenter_63082.jpg
#   inflating: images/329_Previews_60007.jpg
#   inflating: images/328_Underwrite_82285.jpg
#   inflating: images/327_GAB_31441.jpg
#   inflating: images/326_Princesses_60118.jpg
#   inflating: images/325_bedeck_6549.jpg
#   inflating: images/324_COMEDIES_15108.jpg
#   inflating: images/323_palatinate_55088.jpg
#   inflating: images/322_Nongranular_52025.jpg
#   inflating: images/321_hypnotized_37653.jpg
#   inflating: images/320_baileys_5530.jpg
#   inflating: images/319_Convention_16722.jpg
#   inflating: images/318_FLOURISHED_29720.jpg
#   inflating: images/317_Donging_23237.jpg
#   inflating: images/316_CLIMACTIC_14161.jpg
#   inflating: images/315_Bruising_9848.jpg
#   inflating: images/314_Sulk_75986.jpg
#   inflating: images/313_smallholdings_71924.jpg
#   inflating: images/312_grubbily_33974.jpg
#   inflating: images/311_moseyed_49919.jpg
#   inflating: images/310_TENUOUSNESS_78214.jpg
#   inflating: images/309_Final_28941.jpg
#   inflating: images/308_Posh_59024.jpg
#   inflating: images/307_debaters_19542.jpg
#   inflating: images/306_Sanctified_67632.jpg
#   inflating: images/305_POLISHED_58590.jpg
#   inflating: images/304_STAMPEDING_74197.jpg
#   inflating: images/303_kluges_42675.jpg
#   inflating: images/302_attn_4734.jpg
#   inflating: images/301_frameworks_30618.jpg
#   inflating: images/300_CIVILIZATION_13826.jpg
#   inflating: images/299_buybacks_10562.jpg
#   inflating: images/298_ADULATING_1210.jpg
#   inflating: images/297_Agendas_1545.jpg
#   inflating: images/296_boodle_8701.jpg
#   inflating: images/295_friend_30899.jpg
#   inflating: images/294_fatherly_28250.jpg
#   inflating: images/293_IMPLANT_38337.jpg
#   inflating: images/289_AGING_1598.jpg
#   inflating: images/292_caryatids_11797.jpg
#   inflating: images/291_ENCROACHES_25616.jpg
#   inflating: images/290_governess_33264.jpg
#   inflating: images/288_adherents_1018.jpg
#   inflating: images/287_Fleetness_29511.jpg
#   inflating: images/286_WINSOMELY_86815.jpg
#   inflating: images/285_Obstructed_52917.jpg
#   inflating: images/284_MANUEL_46600.jpg
#   inflating: images/283_BBQ_6361.jpg
#   inflating: images/282_Instinctively_39931.jpg
#   inflating: images/281_DELIBERATING_20269.jpg
#   inflating: images/280_details_21132.jpg
#   inflating: images/279_Huntresses_37398.jpg
#   inflating: images/278_synonymous_77035.jpg
#   inflating: images/277_Unitizing_82740.jpg
#   inflating: images/276_Fainest_27918.jpg
#   inflating: images/275_FIREBREAK_29053.jpg
#   inflating: images/274_readerships_62738.jpg
#   inflating: images/273_SPUTUM_73868.jpg
#   inflating: images/272_tablet_77125.jpg
#   inflating: images/271_Overview_54787.jpg
#   inflating: images/270_scramming_68570.jpg
#   inflating: images/269_Boluses_8599.jpg
#   inflating: images/268_Regally_63979.jpg
#   inflating: images/267_Screwball_68649.jpg
#   inflating: images/266_Vicuna_84577.jpg
#   inflating: images/265_Debacle_19520.jpg
#   inflating: images/264_DEFENDANTS_20002.jpg
#   inflating: images/263_VERRUCA_84388.jpg
#   inflating: images/262_buzz_10569.jpg
#   inflating: images/261_gradualness_33333.jpg
#   inflating: images/260_reappoint_62850.jpg
#   inflating: images/259_groundsheets_33911.jpg
#   inflating: images/258_boo_8694.jpg
#   inflating: images/257_droning_23859.jpg
#   inflating: images/256_yevtushenko_87780.jpg
#   inflating: images/255_unwinding_83437.jpg
#   inflating: images/254_reveled_65681.jpg
#   inflating: images/253_hempen_35780.jpg
#   inflating: images/252_featherweights_28388.jpg
#   inflating: images/251_hydrocephalus_37526.jpg
#   inflating: images/250_Employers_25460.jpg
#   inflating: images/249_naphtali_50857.jpg
#   inflating: images/248_PHILIPPINES_57206.jpg
#   inflating: images/247_VERILY_84356.jpg
#   inflating: images/246_Mahicans_46077.jpg
#   inflating: images/245_whelped_86189.jpg
#   inflating: images/244_sobriety_72437.jpg
#   inflating: images/243_hardheadedness_34961.jpg
#   inflating: images/242_Minstrels_48685.jpg
#   inflating: images/241_HAZELNUT_35299.jpg
#   inflating: images/240_DEL_20224.jpg
#   inflating: images/239_Coppola_16925.jpg
#   inflating: images/238_Swisher_76848.jpg
#   inflating: images/237_ANYPLACE_3325.jpg
#   inflating: images/236_qualitatively_61680.jpg
#   inflating: images/235_COBAIN_14538.jpg
#   inflating: images/234_Rudeness_66980.jpg
#   inflating: images/233_OUTDOING_54002.jpg
#   inflating: images/232_NONPRODUCTIVE_52108.jpg
#   inflating: images/231_DREDGER_23747.jpg
#   inflating: images/230_sideswiped_70780.jpg
#   inflating: images/229_Mimicked_48525.jpg
#   inflating: images/228_CARPAL_11675.jpg
#   inflating: images/227_Becker_6511.jpg
#   inflating: images/226_musclemen_50490.jpg
#   inflating: images/225_Ambitions_2394.jpg
#   inflating: images/224_BLAST_7922.jpg
#   inflating: images/223_ADVANCING_1243.jpg
#   inflating: images/222_REQUITED_65030.jpg
#   inflating: images/221_GOATSKIN_32944.jpg
#   inflating: images/220_Bode_8448.jpg
#   inflating: images/219_admen_1088.jpg
#   inflating: images/218_hygiene_37570.jpg
#   inflating: images/217_annotations_2977.jpg
#   inflating: images/216_Hairsplitter_34563.jpg
#   inflating: images/215_BOULES_8976.jpg
#   inflating: images/214_BECAME_6507.jpg
#   inflating: images/213_Stravinsky_75107.jpg
#   inflating: images/212_injecting_39590.jpg
#   inflating: images/211_Fratricides_30688.jpg
#   inflating: images/210_canopy_11233.jpg
#   inflating: images/209_Leguminous_44001.jpg
#   inflating: images/208_AVIONIC_5093.jpg
#   inflating: images/207_ACCEPTATIONS_563.jpg
#   inflating: images/206_RESPONSES_65284.jpg
#   inflating: images/205_NUMBS_52558.jpg
#   inflating: images/204_Dobbing_22986.jpg
#   inflating: images/203_corpse_17126.jpg
#   inflating: images/202_archenemies_3810.jpg
#   inflating: images/201_schoolfellow_68348.jpg
#   inflating: images/200_Openhanded_53468.jpg
#   inflating: images/199_DESCRIPTORS_20955.jpg
#   inflating: images/198_monopolizes_49619.jpg
#   inflating: images/197_JAYWALK_41319.jpg
#   inflating: images/196_unclothe_81916.jpg
#   inflating: images/195_armbands_3973.jpg
#   inflating: images/194_Girdled_32547.jpg
#   inflating: images/193_MOSEYING_49920.jpg
#   inflating: images/192_somalis_72678.jpg
#   inflating: images/191_takeaways_77283.jpg
#   inflating: images/190_BURLIER_10347.jpg
#   inflating: images/189_HOLDOUTS_36475.jpg
#   inflating: images/188_ferrying_28599.jpg
#   inflating: images/187_socialized_72456.jpg
#   inflating: images/186_Blustering_8358.jpg
#   inflating: images/185_prestos_59915.jpg
#   inflating: images/184_courtesies_17564.jpg
#   inflating: images/183_judgments_41875.jpg
#   inflating: images/182_ROACHED_66316.jpg
#   inflating: images/181_WORTH_87311.jpg
#   inflating: images/180_Musics_50538.jpg
#   inflating: images/179_drafting_23615.jpg
#   inflating: images/178_candidates_11134.jpg
#   inflating: images/177_HISTORIANS_36282.jpg
#   inflating: images/176_penitents_56426.jpg
#   inflating: images/175_Commuted_15327.jpg
#   inflating: images/174_Godel_32980.jpg
#   inflating: images/173_Cascading_11811.jpg
#   inflating: images/172_josephus_41746.jpg
#   inflating: images/171_requests_65013.jpg
#   inflating: images/170_BERNOULLI_7088.jpg
#   inflating: images/169_prepackaging_59737.jpg
#   inflating: images/168_SHIRT_70294.jpg
#   inflating: images/167_TWIRLERS_81423.jpg
#   inflating: images/166_TAVERNA_77720.jpg
#   inflating: images/165_Playtime_58174.jpg
#   inflating: images/164_SLENDERER_71640.jpg
#   inflating: images/163_caramelizing_11440.jpg
#   inflating: images/162_Victimization_84556.jpg
#   inflating: images/161_Womanliness_87041.jpg
#   inflating: images/160_compactly_15342.jpg
#   inflating: images/159_ROTTENLY_66747.jpg
#   inflating: images/158_Dullest_24076.jpg
#   inflating: images/157_Whirred_86308.jpg
#   inflating: images/156_Flowchart_29732.jpg
#   inflating: images/155_OUTRUNNING_54171.jpg
#   inflating: images/154_Squabble_73878.jpg
#   inflating: images/153_ELIZABETH_25095.jpg
#   inflating: images/152_Muskoxen_50562.jpg
#   inflating: images/151_ROOMINESS_66614.jpg
#   inflating: images/150_GULLETS_34198.jpg
#   inflating: images/149_agiler_1595.jpg
#   inflating: images/148_DSCHUBBA_23972.jpg
#   inflating: images/147_Musters_50594.jpg
#   inflating: images/146_Astonishment_4505.jpg
#   inflating: images/145_Forfeiture_30300.jpg
#   inflating: images/144_Collaborating_14860.jpg
#   inflating: images/143_Gop_33165.jpg
#   inflating: images/142_Waist_85246.jpg
#   inflating: images/141_Ndjamena_51085.jpg
#   inflating: images/140_sequestrate_69543.jpg
#   inflating: images/139_10_10.jpg
#   inflating: images/138_SINGLETS_71088.jpg
#   inflating: images/137_immaturity_38076.jpg
#   inflating: images/136_betrothing_7246.jpg
#   inflating: images/135_atty_4765.jpg
#   inflating: images/134_Stiffed_74679.jpg
#   inflating: images/133_mobilize_49226.jpg
#   inflating: images/132_saginaw_67378.jpg
#   inflating: images/131_STARTLED_74318.jpg
#   inflating: images/130_Padlocking_54978.jpg
#   inflating: images/129_METALLURGY_48007.jpg
#   inflating: images/128_Trapezoidal_80371.jpg
#   inflating: images/127_Computationally_15582.jpg
#   inflating: images/126_Posher_59025.jpg
#   inflating: images/125_Educated_24657.jpg
#   inflating: images/124_crucify_18353.jpg
#   inflating: images/123_viaducts_84494.jpg
#   inflating: images/122_nonmigratory_52059.jpg
#   inflating: images/121_Cardiologist_11520.jpg
#   inflating: images/120_Wigner_86549.jpg
#   inflating: images/119_medically_47500.jpg
#   inflating: images/118_sorrowful_72846.jpg
#   inflating: images/117_seminarians_69328.jpg
#   inflating: images/116_pineapple_57686.jpg
#   inflating: images/115_TENACITY_78115.jpg
#   inflating: images/114_severin_69732.jpg
#   inflating: images/113_PASTURAGE_55849.jpg
#   inflating: images/112_BLENCHES_7993.jpg
#   inflating: images/111_riven_66281.jpg
#   inflating: images/110_magnetize_46020.jpg
#   inflating: images/109_lacewings_43043.jpg
#   inflating: images/108_AUDITS_4823.jpg
#   inflating: images/107_TRAMWAYS_80129.jpg
#   inflating: images/106_Matricide_47146.jpg
#   inflating: images/105_Unambitious_81716.jpg
#   inflating: images/104_CLUBFOOT_14385.jpg
#   inflating: images/103_LII_44470.jpg
#   inflating: images/102_Carnelian_11628.jpg
#   inflating: images/101_goodtimes_33125.jpg
#   inflating: images/100_Gunshot_34270.jpg
#   inflating: images/99_Meetinghouses_47556.jpg
#   inflating: images/98_WRING_87424.jpg
#   inflating: images/97_Overdosed_54407.jpg
#   inflating: images/96_kinematics_42535.jpg
#   inflating: images/95_Impotently_38429.jpg
#   inflating: images/94_PUSSIER_61475.jpg
#   inflating: images/93_mutter_50642.jpg
#   inflating: images/92_Roweled_66863.jpg
#   inflating: images/91_ANTLERED_3286.jpg
#   inflating: images/90_OVERACHIEVE_54284.jpg
#   inflating: images/89_Abating_195.jpg
#   inflating: images/88_Ardent_3859.jpg
#   inflating: images/87_overrode_54645.jpg
#   inflating: images/86_GROANS_33816.jpg
#   inflating: images/85_aerated_1333.jpg
#   inflating: images/84_airheads_1752.jpg
#   inflating: images/83_ANSWERS_3060.jpg
#   inflating: images/82_psittacosis_60984.jpg
#   inflating: images/81_GIL_32452.jpg
#   inflating: images/80_Beppo_7017.jpg
#   inflating: images/79_commencing_15185.jpg
#   inflating: images/78_misfires_48899.jpg
#   inflating: images/77_MISFILE_48893.jpg
#   inflating: images/76_HEARTWOOD_35497.jpg
#   inflating: images/75_sculptural_68814.jpg
#   inflating: images/74_Damion_19113.jpg
#   inflating: images/73_FORESTER_30270.jpg
#   inflating: images/72_Pacey_54911.jpg
#   inflating: images/71_Complaisant_15453.jpg
#   inflating: images/70_MANNERED_46545.jpg
#   inflating: images/69_MUTINOUSLY_50637.jpg
#   inflating: images/68_Pinkest_57715.jpg
#   inflating: images/67_FUNCTIONARY_31250.jpg
#   inflating: images/66_mastercard_47033.jpg
#   inflating: images/65_CORMICK_17038.jpg
#   inflating: images/64_Calibrates_10870.jpg
#   inflating: images/63_STRIPPERS_75252.jpg
#   inflating: images/62_MESKEL_47932.jpg
#   inflating: images/61_remissly_64525.jpg
#   inflating: images/60_ARGUES_3896.jpg
#   inflating: images/59_Blitz_8075.jpg
#   inflating: images/58_Glossily_32828.jpg
#   inflating: images/57_Antithetical_3272.jpg
#   inflating: images/56_impeller_38241.jpg
#   inflating: images/55_Attaching_4667.jpg
#   inflating: images/54_CANVASBACKS_11281.jpg
#   inflating: images/53_LISTENABLE_44760.jpg
#   inflating: images/52_Tantalizingly_77481.jpg
#   inflating: images/51_refill_63797.jpg
#   inflating: images/50_Gorgeous_33180.jpg
#   inflating: images/49_Planes_58019.jpg
#   inflating: images/48_WEASELING_85812.jpg
#   inflating: images/47_OVERSTEPPED_54719.jpg
#   inflating: images/46_CHARTREUSE_12825.jpg
#   inflating: images/45_Lockups_45031.jpg
#   inflating: images/44_CENTIMETER_12387.jpg
#   inflating: images/43_Wich_86472.jpg
#   inflating: images/42_Lymphatic_45780.jpg
#   inflating: images/41_Hirelings_36255.jpg
#   inflating: images/40_Slur_71887.jpg
#   inflating: images/39_RECRIMINATED_63380.jpg
#   inflating: images/38_procure_60299.jpg
#   inflating: images/37_Contacted_16450.jpg
#   inflating: images/36_Minicams_48614.jpg
#   inflating: images/35_Nagwares_50775.jpg
#   inflating: images/34_COMPULSORIES_15574.jpg
#   inflating: images/33_MISREPRESENTS_49032.jpg
#   inflating: images/32_venn_84262.jpg
#   inflating: images/31_Suzerainty_76588.jpg
#   inflating: images/30_Factories_27858.jpg
#   inflating: images/29_horsier_36917.jpg
#   inflating: images/28_gloating_32770.jpg
#   inflating: images/27_criticizer_18161.jpg
#   inflating: images/26_malaysians_46242.jpg
#   inflating: images/25_Measles_47424.jpg
#   inflating: images/24_Antisocial_3263.jpg
#   inflating: images/23_OCTAVIAN_53033.jpg
#   inflating: images/22_Laryngitis_43439.jpg
#   inflating: images/21_Hosiers_36941.jpg
#   inflating: images/20_Deduces_19900.jpg
#   inflating: images/19_shingling_70230.jpg
#   inflating: images/18_Fuels_31166.jpg
#   inflating: images/17_RELAUNCH_64333.jpg
#   inflating: images/16_DOWNRIVER_23530.jpg
#   inflating: images/15_guttiest_34343.jpg
#   inflating: images/14_Mishearing_48928.jpg
#   inflating: images/13_rwandan_67207.jpg
#   inflating: images/12_anatomically_2702.jpg
#   inflating: images/11_gatecrashing_31877.jpg
#   inflating: images/10_homiletic_36624.jpg
#   inflating: images/9_atishoo_4607.jpg
#   inflating: images/8_apex_3364.jpg
#   inflating: images/7_Pentecost_56486.jpg
#   inflating: images/6_mushers_50511.jpg
#   inflating: images/5_rococo_66444.jpg
#   inflating: images/4_KALB_42084.jpg
#   inflating: images/3_ORTHOGONALITY_53822.jpg
#   inflating: images/2_And_2745.jpg
#   inflating: images/1_OLDFIELD_53270.jpg
#   inflating: images/501_COMPEL_15393.jpg
#   inflating: images/500_OSTRACIZING_53904.jpg
#   inflating: images/499_Wagnerian_85215.jpg
#   inflating: images/498_hewer_35994.jpg
#   inflating: images/497_Rehabilitation_64109.jpg
#   inflating: images/496_brattiest_9274.jpg
#   inflating: images/495_Menages_47727.jpg
#   inflating: images/494_SLICKNESS_71669.jpg
#   inflating: images/493_travelogue_80414.jpg
#   inflating: images/492_TIER_79058.jpg
#   inflating: images/491_Peacemakers_56113.jpg
#   inflating: images/490_Resents_65106.jpg
#   inflating: images/489_Payable_56053.jpg
#   inflating: images/488_GIMPS_32501.jpg
#   inflating: images/487_INTREPID_40483.jpg
#   inflating: images/486_Pitchforked_57858.jpg
#   inflating: images/485_TAUTOLOGICAL_77714.jpg
#   inflating: images/484_STREET_75138.jpg
#   inflating: images/483_Bobsleighs_8438.jpg
#   inflating: images/482_CORIOLIS_17023.jpg
#   inflating: images/481_Ickier_37765.jpg
#   inflating: images/480_Warranting_85511.jpg
#   inflating: images/479_Proxy_60927.jpg
#   inflating: images/478_COSSET_17294.jpg
#   inflating: images/477_Scatological_68200.jpg
#   inflating: images/476_Cardamoms_11495.jpg
#   inflating: images/475_DECIDEDLY_19710.jpg
#   inflating: images/474_Colonialists_14982.jpg
#   inflating: images/473_Xxl_87586.jpg
#   inflating: images/472_Lyrebirds_45807.jpg
#   inflating: images/471_Wheels_86169.jpg
#   inflating: images/470_CLAIMANTS_13848.jpg
#   inflating: images/469_Birthrights_7668.jpg
#   inflating: images/468_TOPCAT_79660.jpg
#   inflating: images/467_tolerably_79499.jpg
#   inflating: images/466_Inspectors_39868.jpg
#   inflating: images/465_SLAYED_71559.jpg
#   inflating: images/464_LITERATES_44793.jpg
#   inflating: images/463_Lexington_44251.jpg
#   inflating: images/462_Desalinizes_20916.jpg
#   inflating: images/461_enquirer_25904.jpg
#   inflating: images/460_Frightening_30922.jpg
#   inflating: images/459_attributed_4751.jpg
#   inflating: images/458_MINDING_48559.jpg
#   inflating: images/457_SEXLESS_69764.jpg
#   inflating: images/456_Breeziest_9437.jpg
#   inflating: images/455_MEGAN_47579.jpg
#   inflating: images/454_Shortish_70448.jpg
#   inflating: images/453_cornelius_17056.jpg
#   inflating: images/452_Leakier_43768.jpg
#   inflating: images/451_heywood_36017.jpg
#   inflating: images/450_Wrecked_87384.jpg
#   inflating: images/449_DIDACTICALLY_21513.jpg
#   inflating: images/448_bobsleighs_8438.jpg
#   inflating: images/447_Waistbands_85248.jpg
#   inflating: images/446_ANTIQUARIANS_3238.jpg
#   inflating: images/445_GRAYER_33571.jpg
#   inflating: images/444_Slitter_71745.jpg
#   inflating: images/443_Indistinguishable_39075.jpg
#   inflating: images/442_Pettiest_57057.jpg
#   inflating: images/441_factorization_27860.jpg
#   inflating: images/440_Idly_37855.jpg
#   inflating: images/439_GAMA_31619.jpg
#   inflating: images/438_blazon_7949.jpg
#   inflating: images/437_SUMMARIZES_76030.jpg
#   inflating: images/436_colostomy_15041.jpg
#   inflating: images/435_Bayberries_6330.jpg
#   inflating: images/434_CEMETERY_12327.jpg
#   inflating: images/433_plutarch_58404.jpg
#   inflating: images/432_Procreated_60284.jpg
#   inflating: images/431_COSSETTED_17298.jpg
#   inflating: images/430_APISHLY_3391.jpg
#   inflating: images/429_HOOPLA_36775.jpg
#   inflating: images/428_Eastbound_24435.jpg
#   inflating: images/427_Perjure_56727.jpg
#   inflating: images/426_epitome_26239.jpg
#   inflating: images/425_disputing_22592.jpg
#   inflating: images/424_unfeasible_82454.jpg
#   inflating: images/423_HAREBELLS_34992.jpg
#   inflating: images/422_BENEDICTORY_6952.jpg
#   inflating: images/421_EMULSIFIES_25499.jpg
#   inflating: images/420_Stewing_74655.jpg
#   inflating: images/419_forbidding_30123.jpg
#   inflating: images/418_metrical_48095.jpg
#   inflating: images/417_pabst_54899.jpg
#   inflating: images/416_rockery_66426.jpg
#   inflating: images/415_Swirling_76843.jpg
#   inflating: images/414_lats_43532.jpg
#   inflating: images/413_breathy_9420.jpg
#   inflating: images/412_Muddled_50199.jpg
#   inflating: images/411_Chiefs_13164.jpg
#   inflating: images/410_Maimed_46121.jpg
#   inflating: images/409_GLOVER_32839.jpg
#   inflating: images/408_Murano_50441.jpg
#   inflating: images/407_BONELESS_8651.jpg
#   inflating: images/406_Ceremonious_12455.jpg
#   inflating: images/405_Antwan_3307.jpg
#   inflating: images/404_Industrialized_39159.jpg
#   inflating: images/403_EVIDENT_26914.jpg
#   inflating: images/402_FATALITIES_28230.jpg
#   inflating: images/401_RESPONSIVELY_65290.jpg
#   inflating: images/400_unsheathed_83208.jpg
#   inflating: images/399_Catteries_12088.jpg
#   inflating: images/398_tapas_77498.jpg
#   inflating: images/397_CANONIZING_11224.jpg
#   inflating: images/396_COEQUAL_14683.jpg
#   inflating: images/395_ALKALOIDS_2052.jpg
#   inflating: images/394_Rareness_62488.jpg
#   inflating: images/393_mckinney_47355.jpg
#   inflating: images/392_BLUNDERBUSSES_8320.jpg
#   inflating: images/391_GANTLETS_31706.jpg
#   inflating: images/390_inserts_39796.jpg
#   inflating: images/389_stagnancy_74106.jpg
#   inflating: images/388_Abscissas_403.jpg
#   inflating: images/387_Outvotes_54239.jpg
#   inflating: images/386_measurement_47433.jpg
#   inflating: images/385_CLOTHS_14333.jpg
#   inflating: images/384_Grog_33823.jpg
#   inflating: images/383_snorkeler_72297.jpg
#   inflating: images/382_Resew_65128.jpg
#   inflating: images/381_congaing_16020.jpg
#   inflating: images/380_vestigial_84444.jpg
#   inflating: images/379_VERGE_84342.jpg
#   inflating: images/378_BICUSPIDS_7363.jpg
#   inflating: images/377_roofless_66592.jpg
#   inflating: images/376_Sleazy_71575.jpg
#   inflating: images/375_Reconnected_63284.jpg
#   inflating: images/374_Performing_56648.jpg
#   inflating: images/373_cronies_18212.jpg
#   inflating: images/372_RESTFULLER_65319.jpg
#   inflating: images/371_Proprietorially_60682.jpg
#   inflating: images/370_warranty_85513.jpg
#   inflating: images/369_Exclusion_27094.jpg
#   inflating: images/368_ARCHITECTONICS_3831.jpg
#   inflating: images/367_predecessor_59519.jpg
#   inflating: images/366_CONGRATULATIONS_16055.jpg
#   inflating: images/365_LS_45469.jpg
#   inflating: images/364_unseeded_83177.jpg
#   inflating: images/363_Gerber_32255.jpg
#   inflating: images/362_Reinvention_64241.jpg
#   inflating: images/361_councilperson_17388.jpg
#   inflating: images/360_Bogyman_8519.jpg
#   inflating: images/359_Hijacked_36137.jpg
#   inflating: images/358_Jumbled_41943.jpg
#   inflating: images/357_SEXOLOGY_69767.jpg
#   inflating: images/356_Quadratics_61611.jpg
#   inflating: images/355_INJECTORS_39594.jpg
#   inflating: images/354_Tunnelings_81159.jpg
#   inflating: images/353_VERSIFIER_84399.jpg
#   inflating: images/352_Gentlemanly_32163.jpg
#   inflating: images/351_admitting_1128.jpg
#   inflating: images/350_DISADVANTAGES_21902.jpg
#   inflating: images/349_Ogles_53190.jpg
#   inflating: images/348_DODDER_23040.jpg
#   inflating: images/347_UPENDED_83501.jpg
#   inflating: images/346_DERMATITIS_20882.jpg
#   inflating: images/345_Furtiveness_31362.jpg
#   inflating: images/344_EXPRESSIBLE_27519.jpg
#   inflating: images/343_EVACUATE_26798.jpg
#   inflating: images/342_morasses_49799.jpg
#   inflating: images/341_grumblings_34007.jpg
#   inflating: images/340_fear_28359.jpg
#   inflating: images/339_DEVIATION_21270.jpg
#   inflating: images/338_incandescence_38656.jpg
#   inflating: images/337_foots_30086.jpg
#   inflating: images/336_Profoundness_60403.jpg
#   inflating: images/335_venting_84276.jpg
#   inflating: images/334_Ramjet_62311.jpg
#   inflating: images/333_olde_53265.jpg
#   inflating: images/332_hydroponically_37561.jpg
#   inflating: images/331_leo_44088.jpg
#   inflating: images/330_Entrenched_26074.jpg
#   inflating: images/329_Valhalla_83921.jpg
#   inflating: images/328_NONELASTIC_51986.jpg
#   inflating: images/327_deodorized_20665.jpg
#   inflating: images/326_miserably_48884.jpg
#   inflating: images/325_BRAHMA_9160.jpg
#   inflating: images/324_upgrade_83505.jpg
#   inflating: images/323_devotee_21310.jpg
#   inflating: images/322_Microcircuits_48202.jpg
#   inflating: images/321_PYLORUS_61544.jpg
#   inflating: images/320_ASHANTI_4226.jpg
#   inflating: images/319_SLAUGHTERS_71538.jpg
#   inflating: images/318_saintlike_67417.jpg
#   inflating: images/317_FEATHERLESS_28385.jpg
#   inflating: images/316_valhalla_83921.jpg
#   inflating: images/315_VERMIFORM_84368.jpg
#   inflating: images/314_hosteling_36967.jpg
#   inflating: images/313_PLETHORA_58246.jpg
#   inflating: images/312_rolodex_66526.jpg
#   inflating: images/311_HEADBUTT_35329.jpg
#   inflating: images/310_disincentive_22349.jpg
#   inflating: images/309_Hence_35787.jpg
#   inflating: images/308_Cardsharps_11530.jpg
#   inflating: images/307_Subsidize_75690.jpg
#   inflating: images/306_emulsifiers_25498.jpg
#   inflating: images/305_manumitted_46612.jpg
#   inflating: images/304_Nickname_51586.jpg
#   inflating: images/303_DIPPIER_21820.jpg
#   inflating: images/302_Tehran_77928.jpg
#   inflating: images/301_broader_9678.jpg
#   inflating: images/300_Velodromes_84214.jpg
#   inflating: images/299_Scalpel_68084.jpg
#   inflating: images/298_CENOZOIC_12333.jpg
#   inflating: images/297_SIRLOINS_71146.jpg
#   inflating: images/296_Rutty_67203.jpg
#   inflating: images/295_Pathogenic_55902.jpg
#   inflating: images/294_preoccupies_59725.jpg
#   inflating: images/293_DEFYING_20148.jpg
#   inflating: images/292_betrayals_7235.jpg
#   inflating: images/291_benzine_7015.jpg
#   inflating: images/290_racer_62038.jpg
#   inflating: images/289_Bullfrog_10132.jpg
#   inflating: images/288_Paler_55115.jpg
#   inflating: images/287_Unsafer_83127.jpg
#   inflating: images/286_jacks_41118.jpg
#   inflating: images/285_WANTED_85417.jpg
#   inflating: images/284_bunghole_10231.jpg
#   inflating: images/283_croce_18184.jpg
#   inflating: images/282_Wm_86976.jpg
#   inflating: images/281_bottled_8946.jpg
#   inflating: images/280_Grandaunts_33384.jpg
#   inflating: images/279_Medan_47471.jpg
#   inflating: images/278_lean_43774.jpg
#   inflating: images/277_cowper_17665.jpg
#   inflating: images/276_Bathe_6226.jpg
#   inflating: images/275_Machiavelli_45866.jpg
#   inflating: images/274_Garret_31795.jpg
#   inflating: images/273_Workaholics_87204.jpg
#   inflating: images/272_SPORED_73671.jpg
#   inflating: images/271_melinda_47632.jpg
#   inflating: images/270_MITCHELL_49149.jpg
#   inflating: images/269_NECKING_51144.jpg
#   inflating: images/268_Pecuniary_56203.jpg
#   inflating: images/267_Oversupplies_54743.jpg
#   inflating: images/266_perspicuous_56891.jpg
#   inflating: images/265_Lairds_43141.jpg
#   inflating: images/264_sanctimonious_67636.jpg
#   inflating: images/261_MAGYAR_46058.jpg
#   inflating: images/263_FRISIANS_30951.jpg
#   inflating: images/262_ALABAMANS_1832.jpg
#   inflating: images/260_Rodin_66456.jpg
#   inflating: images/259_Splodge_73576.jpg
#   inflating: images/258_estranged_26632.jpg
#   inflating: images/257_marshmallow_46890.jpg
#   inflating: images/256_Decaffeinating_19622.jpg
#   inflating: images/255_Xxi_87581.jpg
#   inflating: images/254_lambswool_43190.jpg
#   inflating: images/253_LXIV_45758.jpg
#   inflating: images/252_stop_74912.jpg
#   inflating: images/251_Mutter_50642.jpg
#   inflating: images/250_OUTSTANDING_54218.jpg
#   inflating: images/249_intellect_40049.jpg
#   inflating: images/248_Wager_85195.jpg
#   inflating: images/247_BRAIDING_9172.jpg
#   inflating: images/246_balling_5645.jpg
#   inflating: images/245_overcareful_54353.jpg
#   inflating: images/244_Grower_33952.jpg
#   inflating: images/243_absenteeism_420.jpg
#   inflating: images/242_Turn_81228.jpg
#   inflating: images/241_ALLITERATING_2124.jpg
#   inflating: images/240_theocratic_78522.jpg
#   inflating: images/239_CONDUCTING_15837.jpg
#   inflating: images/238_Reweighing_65847.jpg
#   inflating: images/237_gallbladder_31559.jpg
#   inflating: images/236_casework_11828.jpg
#   inflating: images/235_twaddling_81331.jpg
#   inflating: images/234_munitioned_50429.jpg
#   inflating: images/233_CABINETS_10653.jpg
#   inflating: images/232_Shovel_70486.jpg
#   inflating: images/231_dismounted_22442.jpg
#   inflating: images/230_STURDY_75451.jpg
#   inflating: images/229_socialistic_72450.jpg
#   inflating: images/228_Jaycee_41313.jpg
#   inflating: images/227_Addenda_955.jpg
#   inflating: images/226_topographers_79684.jpg
#   inflating: images/225_alphabetizer_2223.jpg
#   inflating: images/224_dampeners_19132.jpg
#   inflating: images/223_TRIALED_80569.jpg
#   inflating: images/222_TILDES_79095.jpg
#   inflating: images/221_Bedridden_6582.jpg
#   inflating: images/220_Stretchy_75183.jpg
#   inflating: images/219_Incipient_38730.jpg
#   inflating: images/218_PERSPIRE_56893.jpg
#   inflating: images/217_universalize_82750.jpg
#   inflating: images/216_soldiering_72568.jpg
#   inflating: images/215_Committal_15252.jpg
#   inflating: images/214_indelibly_38955.jpg
#   inflating: images/213_Cooling_16847.jpg
#   inflating: images/212_Sickbed_70709.jpg
#   inflating: images/211_massifs_47022.jpg
#   inflating: images/210_Transcendentalism_80164.jpg
#   inflating: images/209_cooled_16839.jpg
#   inflating: images/208_Corny_17094.jpg
#   inflating: images/207_SKIMPILY_71316.jpg
#   inflating: images/206_Pages_55002.jpg
#   inflating: images/205_Misdiagnosing_48868.jpg
#   inflating: images/204_wilkes_86606.jpg
#   inflating: images/203_Vociferating_84964.jpg
#   inflating: images/202_sash_67822.jpg
#   inflating: images/201_Cosseted_17295.jpg
#   inflating: images/200_Crenelating_18013.jpg
#   inflating: images/199_COLLIER_14933.jpg
#   inflating: images/198_Frame_30612.jpg
#   inflating: images/197_TEDIOUSNESS_77890.jpg
#   inflating: images/196_COPYBOOK_16943.jpg
#   inflating: images/195_Nieces_51603.jpg
#   inflating: images/194_ravage_62617.jpg
#   inflating: images/193_locking_45022.jpg
#   inflating: images/192_Impasse_38200.jpg
#   inflating: images/191_Citronella_13809.jpg
#   inflating: images/190_REASONABLENESS_62897.jpg
#   inflating: images/189_domesticated_23178.jpg
#   inflating: images/188_intensified_40081.jpg
#   inflating: images/187_Tupperware_81169.jpg
#   inflating: images/186_DOWNIEST_23514.jpg
#   inflating: images/185_Nugatory_52528.jpg
#   inflating: images/184_WALLPAPERS_85352.jpg
#   inflating: images/183_BROADCASTER_9669.jpg
#   inflating: images/182_expecting_27354.jpg
#   inflating: images/181_Prohibitory_60459.jpg
#   inflating: images/180_Tallier_77337.jpg
#   inflating: images/179_Darby_19222.jpg
#   inflating: images/178_LIFTER_44419.jpg
#   inflating: images/177_CRIOLLO_18117.jpg
#   inflating: images/176_movables_50125.jpg
#   inflating: images/175_vertical_84417.jpg
#   inflating: images/174_Fiefs_28782.jpg
#   inflating: images/173_Sojourner_72546.jpg
#   inflating: images/172_butt_10510.jpg
#   inflating: images/171_ZAPPY_87962.jpg
#   inflating: images/170_UNABRIDGEDS_81679.jpg
#   inflating: images/169_Propagators_60599.jpg
#   inflating: images/168_greece_33607.jpg
#   inflating: images/167_remeasuring_64484.jpg
#   inflating: images/166_STUNK_75418.jpg
#   inflating: images/165_SYMBIOSIS_76950.jpg
#   inflating: images/164_Whipped_86276.jpg
#   inflating: images/163_Elevates_25041.jpg
#   inflating: images/162_BARER_5946.jpg
#   inflating: images/161_HITACHI_36296.jpg
#   inflating: images/160_Regrettable_64058.jpg
#   inflating: images/159_HORSERADISH_36899.jpg
#   inflating: images/158_copped_16915.jpg
#   inflating: images/157_Narrower_50917.jpg
#   inflating: images/142_risers_66233.jpg
#   inflating: images/156_Highness_36124.jpg
#   inflating: images/155_typecasts_81488.jpg
#   inflating: images/154_Uttering_83795.jpg
#   inflating: images/153_DISCLOSES_22047.jpg
#   inflating: images/152_Trisected_80745.jpg
#   inflating: images/151_Unattractive_81751.jpg
#   inflating: images/150_cultivation_18597.jpg
#   inflating: images/149_Cottagers_17341.jpg
#   inflating: images/148_Complicit_15490.jpg
#   inflating: images/147_Pawnbrokers_56040.jpg
#   inflating: images/146_CUTOUTS_18865.jpg
#   inflating: images/145_Memorialize_47702.jpg
#   inflating: images/144_Encouraged_25608.jpg
#   inflating: images/143_Compartmentalizes_15374.jpg
#   inflating: images/141_AUTOMATION_4989.jpg
#   inflating: images/140_GANGSTA_31694.jpg
#   inflating: images/139_Mislays_48964.jpg
#   inflating: images/138_UNJUSTIFIABLE_82765.jpg
#   inflating: images/137_STRADDLED_74996.jpg
#   inflating: images/136_HEAVIES_35532.jpg
#   inflating: images/135_CONCEIVABLE_15632.jpg
#   inflating: images/134_WINDUPS_86745.jpg
#   inflating: images/133_radioactively_62115.jpg
#   inflating: images/132_Residents_65158.jpg
#   inflating: images/131_GOLFING_33068.jpg
#   inflating: images/130_overextending_54465.jpg
#   inflating: images/129_Daylights_19395.jpg
#   inflating: images/128_Disrespect_22616.jpg
#   inflating: images/127_NEWSREADERS_51505.jpg
#   inflating: images/126_subduing_75548.jpg
#   inflating: images/125_humanizes_37259.jpg
#   inflating: images/124_peafowl_56125.jpg
#   inflating: images/123_Trivial_80776.jpg
#   inflating: images/122_strew_75184.jpg
#   inflating: images/121_tonics_79594.jpg
#   inflating: images/120_QUEASIER_61770.jpg
#   inflating: images/119_MANEUVER_46436.jpg
#   inflating: images/118_darnell_19266.jpg
#   inflating: images/117_Slunk_71886.jpg
#   inflating: images/116_pagan_54989.jpg
#   inflating: images/115_DISABLEMENT_21891.jpg
#   inflating: images/114_Unification_82640.jpg
#   inflating: images/113_Wingstreet_86777.jpg
#   inflating: images/112_Trug_80942.jpg
#   inflating: images/111_SEAWORTHIER_68980.jpg
#   inflating: images/110_archfiend_3820.jpg
#   inflating: images/109_Jelling_41378.jpg
#   inflating: images/108_Gothic_33228.jpg
#   inflating: images/107_ELECTROLOGIST_24988.jpg
#   inflating: images/106_VILLAGES_84660.jpg
#   inflating: images/105_zapotec_87956.jpg
#   inflating: images/104_colon_14974.jpg
#   inflating: images/103_PITON_57886.jpg
#   inflating: images/102_Barons_6036.jpg
#   inflating: images/101_trombonist_80812.jpg
#   inflating: images/100_acclaimed_591.jpg
#   inflating: images/99_Elbowroom_24923.jpg
#   inflating: images/98_FAFNIR_27893.jpg
#   inflating: images/97_choirmaster_13388.jpg
#   inflating: images/96_FLOODING_29635.jpg
#   inflating: images/95_Prerecording_59790.jpg
#   inflating: images/94_Bullocks_10149.jpg
#   inflating: images/93_majorly_46188.jpg
#   inflating: images/92_CHESTER_13074.jpg
#   inflating: images/91_repentance_64779.jpg
#   inflating: images/90_Middlebrow_48272.jpg
#   inflating: images/89_lye_45772.jpg
#   inflating: images/88_Mansion_46571.jpg
#   inflating: images/87_Tanned_77462.jpg
#   inflating: images/86_SING_71064.jpg
#   inflating: images/85_PEREMPTORY_56608.jpg
#   inflating: images/84_jaggies_41153.jpg
#   inflating: images/83_Sprees_73761.jpg
#   inflating: images/82_artificers_4144.jpg
#   inflating: images/81_Auditing_4813.jpg
#   inflating: images/80_Testify_78374.jpg
#   inflating: images/79_inflammations_39369.jpg
#   inflating: images/78_Nicaragua_51553.jpg
#   inflating: images/77_NY_52673.jpg
#   inflating: images/76_fathomable_28253.jpg
#   inflating: images/75_Gershwin_32293.jpg
#   inflating: images/74_doddered_23041.jpg
#   inflating: images/73_ragbag_62179.jpg
#   inflating: images/72_VOLUNTEERS_85041.jpg
#   inflating: images/71_Feted_28651.jpg
#   inflating: images/70_iterating_41030.jpg
#   inflating: images/69_DODOS_23060.jpg
#   inflating: images/68_Creations_17937.jpg
#   inflating: images/67_ANODIZED_3018.jpg
#   inflating: images/66_snarl_72154.jpg
#   inflating: images/65_Texans_78418.jpg
#   inflating: images/64_DREADNOUGHTS_23719.jpg
#   inflating: images/63_Photoengrave_57318.jpg
#   inflating: images/62_cliques_14228.jpg
#   inflating: images/61_nauseated_51029.jpg
#   inflating: images/60_DECENNIAL_19691.jpg
#   inflating: images/59_burgundian_10331.jpg
#   inflating: images/58_Scrooge_68711.jpg
#   inflating: images/57_bose_8897.jpg
#   inflating: images/56_Surrounded_76502.jpg
#   inflating: images/55_Sluggishness_71859.jpg
#   inflating: images/54_TYCHO_81470.jpg
#   inflating: images/53_seethes_69171.jpg
#   inflating: images/52_LINEAR_44607.jpg
#   inflating: images/51_sardines_67795.jpg
#   inflating: images/50_ORGANIZATIONAL_53711.jpg
#   inflating: images/49_Malarial_46228.jpg
#   inflating: images/48_Leader_43736.jpg
#   inflating: images/47_COLLECTIVIST_14910.jpg
#   inflating: images/46_kuwaiti_42973.jpg
#   inflating: images/45_imperturbably_38311.jpg
#   inflating: images/44_Daisies_19071.jpg
#   inflating: images/43_MIDYEARS_48333.jpg
#   inflating: images/42_VETERINARY_84464.jpg
#   inflating: images/41_Penelope_56398.jpg
#   inflating: images/40_Styptics_75488.jpg
#   inflating: images/39_cobs_14557.jpg
#   inflating: images/38_posthumously_59098.jpg
#   inflating: images/37_axletrees_5193.jpg
#   inflating: images/36_FUSES_31372.jpg
#   inflating: images/35_Extricate_27699.jpg
#   inflating: images/34_hows_37139.jpg
#   inflating: images/33_dilemmas_21665.jpg
#   inflating: images/32_Ornamenting_53782.jpg
#   inflating: images/31_RESCINDED_65060.jpg
#   inflating: images/30_gilmore_32478.jpg
# ...
#   inflating: images/313_ACCESSIBLY_572.jpg
#   inflating: images/312_adhesion_1021.jpg
#   inflating: images/311_Desuetude_21119.jpg
#   inflating: images/310_ADVERSE_1279.jpg
#   inflating: images/309_HELLMAN_35706.jpg
#   inflating: images/308_KIDDED_42432.jpg
#   inflating: images/307_MILLIONAIRE_48475.jpg
#   inflating: images/306_Barometric_6023.jpg
#   inflating: images/305_DEICER_20194.jpg
#   inflating: images/304_Winiest_86781.jpg
#   inflating: images/303_CUMMERBUND_18620.jpg
#   inflating: images/302_KNICKERBOCKER_42727.jpg
#   inflating: images/301_Puttying_61521.jpg
#   inflating: images/300_Blurs_8343.jpg
#   inflating: images/299_DISCOMFIT_22067.jpg
#   inflating: images/298_curvatures_18786.jpg
#   inflating: images/297_Stumped_75409.jpg
#   inflating: images/296_Venezuelans_84253.jpg
#   inflating: images/295_ALEXANDERS_1949.jpg
#   inflating: images/294_EBBITT_24475.jpg
#   inflating: images/293_NEWER_51457.jpg
#   inflating: images/292_Firecracker_29059.jpg
#   inflating: images/291_Unwariness_83415.jpg
#   inflating: images/290_Interwove_40419.jpg
#   inflating: images/289_AUDITING_4813.jpg
#   inflating: images/288_Derogate_20889.jpg
#   inflating: images/287_Specificity_73208.jpg
#   inflating: images/286_MONK_49550.jpg
#   inflating: images/285_Dismally_22418.jpg
#   inflating: images/284_brownouts_9821.jpg
#   inflating: images/283_steerage_74516.jpg
#   inflating: images/282_MYRIADS_50691.jpg
#   inflating: images/281_Subtext_75753.jpg
#   inflating: images/280_PIGHEADEDNESS_57560.jpg
#   inflating: images/279_ROBESPIERRE_66388.jpg
#   inflating: images/278_UNFEASIBLE_82454.jpg
#   inflating: images/277_Missourian_49064.jpg
#   inflating: images/276_chronologists_13543.jpg
#   inflating: images/275_INVALIDISM_40568.jpg
#   inflating: images/274_PERUSALS_56936.jpg
#   inflating: images/273_MOPER_49764.jpg
#   inflating: images/272_Archly_3846.jpg
#   inflating: images/271_nursed_52601.jpg
#   inflating: images/270_Reverends_65712.jpg
#   inflating: images/269_Danelaw_19176.jpg
#   inflating: images/268_CARFARE_11568.jpg
#   inflating: images/267_squeaked_73941.jpg
#   inflating: images/266_Floss_29691.jpg
#   inflating: images/265_gnaws_32904.jpg
#   inflating: images/264_Blazoned_7950.jpg
#   inflating: images/263_warble_85429.jpg
#   inflating: images/262_execs_27158.jpg
#   inflating: images/261_BLURT_8344.jpg
#   inflating: images/260_Habitual_34441.jpg
#   inflating: images/259_SCUMMY_68826.jpg
#   inflating: images/258_GETAWAY_32321.jpg
#   inflating: images/257_Proximate_60925.jpg
#   inflating: images/256_AMBULANCE_2409.jpg
#   inflating: images/255_CONSECRATE_16216.jpg
#   inflating: images/254_DISTRIBUTORSHIPS_22806.jpg
#   inflating: images/253_Verizon_84363.jpg
#   inflating: images/252_Unloose_82836.jpg
#   inflating: images/251_STREETWISE_75148.jpg
#   inflating: images/250_mosque_49927.jpg
#   inflating: images/249_inexperience_39248.jpg
#   inflating: images/248_stock_74798.jpg
#   inflating: images/247_Paperhangers_55358.jpg
#   inflating: images/246_Crawdad_17866.jpg
#   inflating: images/245_ROUSTED_66822.jpg
#   inflating: images/244_BRONC_9737.jpg
#   inflating: images/243_XEONIX_87539.jpg
#   inflating: images/242_formulate_30391.jpg
#   inflating: images/241_MOONING_49719.jpg
#   inflating: images/240_hoops_36776.jpg
#   inflating: images/239_paraguayan_55425.jpg
#   inflating: images/238_Datelining_19327.jpg
#   inflating: images/237_gilder_32460.jpg
#   inflating: images/236_errs_26444.jpg
#   inflating: images/235_Panossian_55290.jpg
#   inflating: images/234_Starkly_74295.jpg
#   inflating: images/233_Spiffy_73401.jpg
#   inflating: images/232_PENMANSHIP_56432.jpg
#   inflating: images/231_PASTEL_55813.jpg
#   inflating: images/230_GAS_31822.jpg
#   inflating: images/229_bohr_8527.jpg
#   inflating: images/228_premised_59702.jpg
#   inflating: images/227_prescott_59822.jpg
#   inflating: images/226_Snowplows_72358.jpg
#   inflating: images/225_DEVASTATING_21246.jpg
#   inflating: images/224_Throwaway_78873.jpg
#   inflating: images/223_estuary_26642.jpg
#   inflating: images/222_Loosen_45242.jpg
#   inflating: images/221_misfiles_48895.jpg
#   inflating: images/220_crying_18464.jpg
#   inflating: images/219_FROSTBITING_31047.jpg
#   inflating: images/218_nontaxable_52187.jpg
#   inflating: images/217_zigzagging_88036.jpg
#   inflating: images/216_Wailers_85234.jpg
#   inflating: images/215_Spamming_73058.jpg
#   inflating: images/214_ensues_25960.jpg
#   inflating: images/213_riffles_66073.jpg
#   inflating: images/212_Theatrical_78490.jpg
#   inflating: images/211_Mongers_49521.jpg
#   inflating: images/210_REFINERS_63812.jpg
#   inflating: images/209_FLETCHER_29528.jpg
#   inflating: images/208_WINDSTORMS_86736.jpg
#   inflating: images/207_Reviving_65789.jpg
#   inflating: images/206_holden_36469.jpg
#   inflating: images/205_Cheetahs_13012.jpg
#   inflating: images/204_unable_81677.jpg
#   inflating: images/203_discreditably_22163.jpg
#   inflating: images/202_FICTIONALIZES_28750.jpg
#   inflating: images/201_Palestinians_55121.jpg
#   inflating: images/200_Lizzy_44906.jpg
#   inflating: images/199_REGIMENTED_64015.jpg
#   inflating: images/198_antiquarians_3238.jpg
#   inflating: images/197_analogizing_2653.jpg
#   inflating: images/196_Ballpoint_5662.jpg
#   inflating: images/195_Classiest_13975.jpg
#   inflating: images/194_SUBAREA_75506.jpg
#   inflating: images/193_EXERCISE_27194.jpg
#   inflating: images/192_COATINGS_14519.jpg
#   inflating: images/191_BLOODHOUNDS_8148.jpg
#   inflating: images/190_Polyester_58673.jpg
#   inflating: images/189_cover_17600.jpg
#   inflating: images/188_SMUDGY_72073.jpg
#   inflating: images/187_radiant_62092.jpg
#   inflating: images/186_spook_73642.jpg
#   inflating: images/185_Scandinavian_68114.jpg
#   inflating: images/184_BOOB_8695.jpg
#   inflating: images/183_TIPPY_79276.jpg
#   inflating: images/182_SECTIONAL_69048.jpg
#   inflating: images/181_Recrudescence_63392.jpg
#   inflating: images/180_Moho_49345.jpg
#   inflating: images/179_palatalized_55080.jpg
#   inflating: images/178_church_13605.jpg
#   inflating: images/177_unobstructed_82923.jpg
#   inflating: images/176_spillovers_73419.jpg
#   inflating: images/175_Pharisees_57125.jpg
#   inflating: images/174_isidro_40926.jpg
#   inflating: images/173_Cosmos_17287.jpg
#   inflating: images/172_RELIVED_64420.jpg
#   inflating: images/171_jetting_41471.jpg
#   inflating: images/170_Perjury_56734.jpg
#   inflating: images/169_Choice_13381.jpg
#   inflating: images/168_VERMONTER_84373.jpg
#   inflating: images/167_Novella_52444.jpg
#   inflating: images/166_leavers_43839.jpg
#   inflating: images/165_Jocelyn_41618.jpg
#   inflating: images/164_GLOBAL_32774.jpg
#   inflating: images/163_Attains_4684.jpg
#   inflating: images/162_Bacteriologists_5448.jpg
#   inflating: images/161_BASTERS_6208.jpg
#   inflating: images/160_Impoverished_38435.jpg
#   inflating: images/159_ERGS_26383.jpg
#   inflating: images/158_TAEJON_77206.jpg
#   inflating: images/157_INSTRUCTIVE_39956.jpg
#   inflating: images/156_BOBSLEIGHS_8438.jpg
#   inflating: images/155_appropriate_3624.jpg
#   inflating: images/154_CORRECTABLE_17142.jpg
#   inflating: images/153_ENTREPRENEURSHIP_26082.jpg
#   inflating: images/152_SILENCED_70908.jpg
#   inflating: images/151_Phylum_57382.jpg
#   inflating: images/150_suffixed_75898.jpg
#   inflating: images/149_Kornberg_42873.jpg
#   inflating: images/148_OVERTHROWN_54759.jpg
#   inflating: images/147_SUDANESE_75860.jpg
#   inflating: images/146_dildo_21662.jpg
#   inflating: images/145_Milliliter_48465.jpg
#   inflating: images/144_Attributives_4758.jpg
#   inflating: images/143_marring_46865.jpg
#   inflating: images/142_Withdraw_86911.jpg
#   inflating: images/141_Garb_31722.jpg
#   inflating: images/140_Appendages_3494.jpg
#   inflating: images/139_boulevards_8978.jpg
#   inflating: images/138_nybbling_52678.jpg
#   inflating: images/137_INCOMER_38778.jpg
#   inflating: images/136_OVERBOOK_54329.jpg
#   inflating: images/135_shopped_70401.jpg
#   inflating: images/134_MOSQUITO_49929.jpg
#   inflating: images/133_constipates_16354.jpg
#   inflating: images/132_Hooked_36758.jpg
#   inflating: images/131_VATICAN_84109.jpg
#   inflating: images/130_Gradate_33315.jpg
#   inflating: images/129_FOXHOLE_30551.jpg
#   inflating: images/128_ROUNDISH_66805.jpg
#   inflating: images/127_indited_39078.jpg
#   inflating: images/126_Sectioned_69051.jpg
#   inflating: images/125_ENNOBLES_25888.jpg
#   inflating: images/124_cartographer_11763.jpg
#   inflating: images/123_REMUNERATIONS_64591.jpg
#   inflating: images/122_Prearrange_59419.jpg
#   inflating: images/121_RETRACING_65536.jpg
#   inflating: images/120_Balkan_5611.jpg
#   inflating: images/119_Earnestine_24374.jpg
#   inflating: images/118_COMPLICIT_15490.jpg
#   inflating: images/117_notion_52404.jpg
#   inflating: images/116_remind_64507.jpg
#   inflating: images/115_MUSIAL_50522.jpg
#   inflating: images/114_Yves_87923.jpg
#   inflating: images/113_ginny_32521.jpg
#   inflating: images/112_Lobotomize_44981.jpg
#   inflating: images/111_Reexplained_63746.jpg
#   inflating: images/110_blindsiding_8042.jpg
#   inflating: images/109_GRANOLA_33440.jpg
#   inflating: images/108_inoculation_39689.jpg
#   inflating: images/107_Anarchistic_2686.jpg
#   inflating: images/106_limiters_44550.jpg
#   inflating: images/105_GLASSINESS_32677.jpg
#   inflating: images/104_Dry_23961.jpg
#   inflating: images/103_quirked_61932.jpg
#   inflating: images/102_refresher_63907.jpg
#   inflating: images/101_Sambo_67589.jpg
#   inflating: images/100_SUPPURATING_76388.jpg
#   inflating: images/99_sensationally_69416.jpg
#   inflating: images/98_LUGOSI_45571.jpg
#   inflating: images/97_sauteed_67951.jpg
#   inflating: images/96_ARUM_4175.jpg
#   inflating: images/95_kaddishes_42063.jpg
#   inflating: images/94_Homeyness_36617.jpg
#   inflating: images/93_Airfields_1745.jpg
#   inflating: images/92_treading_80446.jpg
#   inflating: images/91_Superstates_76289.jpg
#   inflating: images/90_Ellipsoidal_25113.jpg
#   inflating: images/89_filer_28864.jpg
#   inflating: images/88_curia_18697.jpg
#   inflating: images/87_Rudder_66971.jpg
#   inflating: images/86_Blarney_7907.jpg
#   inflating: images/85_COMFORT_15130.jpg
#   inflating: images/84_SCALPS_68089.jpg
#   inflating: images/83_Breadwinner_9348.jpg
#   inflating: images/82_Goddaughter_32976.jpg
#   inflating: images/81_courtrooms_17578.jpg
#   inflating: images/80_Candlewicks_11153.jpg
#   inflating: images/79_PSYCHEDELIA_60991.jpg
#   inflating: images/78_Deigns_20207.jpg
#   inflating: images/77_BARRENEST_6062.jpg
#   inflating: images/76_Berg_7042.jpg
#   inflating: images/75_Menaces_47721.jpg
#   inflating: images/74_Distastes_22735.jpg
#   inflating: images/73_FERNANDEZ_28571.jpg
#   inflating: images/72_EXPEDITES_27374.jpg
#   inflating: images/71_spites_73503.jpg
#   inflating: images/70_MACINTOSH_45887.jpg
#   inflating: images/69_MOLDY_49400.jpg
#   inflating: images/68_1996_46.jpg
#   inflating: images/67_Ultrasounds_81634.jpg
#   inflating: images/66_DETACHES_21125.jpg
#   inflating: images/65_GALVANIZING_31614.jpg
#   inflating: images/64_Stegosaurus_74525.jpg
#   inflating: images/63_Potbellies_59170.jpg
#   inflating: images/62_Trap_80363.jpg
#   inflating: images/61_seismographers_69214.jpg
#   inflating: images/60_Revolutionist_65806.jpg
#   inflating: images/59_Burdock_10287.jpg
#   inflating: images/58_REINVENTED_64239.jpg
#   inflating: images/57_Moneymaker_49514.jpg
#   inflating: images/56_tn_79374.jpg
#   inflating: images/55_SCORNFULLY_68492.jpg
#   inflating: images/54_gauntest_31926.jpg
#   inflating: images/53_fitful_29190.jpg
#   inflating: images/52_gradual_33330.jpg
#   inflating: images/51_CLOSURES_14317.jpg
#   inflating: images/50_account_647.jpg
#   inflating: images/49_Animadverting_2897.jpg
#   inflating: images/48_restatements_65309.jpg
#   inflating: images/47_Sandlots_67684.jpg
#   inflating: images/46_ADVERT_1286.jpg
#   inflating: images/45_Heinousness_35644.jpg
#   inflating: images/44_CHATTERERS_12882.jpg
#   inflating: images/43_Applauder_3516.jpg
#   inflating: images/42_existentialists_27276.jpg
#   inflating: images/41_TECHIE_77854.jpg
#   inflating: images/40_Chekhovian_13018.jpg
#   inflating: images/39_rampart_62327.jpg
#   inflating: images/38_derelict_20859.jpg
#   inflating: images/37_ANGELINA_2820.jpg
#   inflating: images/36_Agglomeration_1555.jpg
#   inflating: images/35_Recitatives_63155.jpg
#   inflating: images/34_adduce_989.jpg
#   inflating: images/33_leafs_43754.jpg
#   inflating: images/32_Silverware_70971.jpg
#   inflating: images/31_MOTORED_50018.jpg
#   inflating: images/30_conciliates_15699.jpg
#   inflating: images/29_Snowshoe_72361.jpg
#   inflating: images/28_Fleeciest_29497.jpg
#   inflating: images/27_Sedentary_69089.jpg
#   inflating: images/26_patronymically_55974.jpg
#   inflating: images/25_Analogy_2660.jpg
#   inflating: images/24_pygmies_61537.jpg
#   inflating: images/23_Toy_79965.jpg
#   inflating: images/22_Wittered_86949.jpg
#   inflating: images/21_ritalin_66256.jpg
#   inflating: images/20_illimitable_37954.jpg
#   inflating: images/19_entrusting_26088.jpg
#   inflating: images/18_LATERALLY_43496.jpg
#   inflating: images/17_trampers_80114.jpg
#   inflating: images/16_Emory_25407.jpg
#   inflating: images/15_homo_36631.jpg
#   inflating: images/14_adorns_1182.jpg
#   inflating: images/13_kluges_42675.jpg
#   inflating: images/12_Unstinting_83270.jpg
#   inflating: images/11_DROLL_23847.jpg
#   inflating: images/10_Corvette_17242.jpg
#   inflating: images/9_Windflower_86695.jpg
#   inflating: images/8_wolfish_87017.jpg
#   inflating: images/7_Expatriation_27345.jpg
#   inflating: images/6_dinners_21770.jpg
#   inflating: images/5_Naphthalene_50859.jpg
#   inflating: images/4_Pats_55978.jpg
#   inflating: images/3_VIEWS_84619.jpg
#   inflating: images/2_Iterator_41034.jpg
#   inflating: images/1_inoffensively_39692.jpg
#   inflating: images/501_bivouacked_7744.jpg
#   inflating: images/500_Prepubescence_59781.jpg
#   inflating: images/499_ancientest_2739.jpg
#   inflating: images/498_ALAMBRES_1840.jpg
#   inflating: images/497_Sodomite_72495.jpg
#   inflating: images/496_tamales_77362.jpg
#   inflating: images/495_annam_2943.jpg
#   inflating: images/494_Studioplex_75376.jpg
#   inflating: images/493_SAVOY_67992.jpg
#   inflating: images/492_Trivializing_80783.jpg
#   inflating: images/491_Gino_32522.jpg
#   inflating: images/490_STOICISM_74847.jpg
#   inflating: images/489_nineveh_51717.jpg
#   inflating: images/488_pearl_56142.jpg
#   inflating: images/487_grosz_33873.jpg
#   inflating: images/486_workshy_87249.jpg
#   inflating: images/485_CONSES_16259.jpg
#   inflating: images/484_baggy_5504.jpg
#   inflating: images/483_plotted_58297.jpg
#   inflating: images/482_tupungato_81170.jpg
#   inflating: images/481_HALFBACKS_34603.jpg
#   inflating: images/480_Jeffery_41365.jpg
#   inflating: images/479_Tormentors_79733.jpg
#   inflating: images/478_dropsical_23885.jpg
#   inflating: images/477_paez_54988.jpg
#   inflating: images/476_Annealing_2949.jpg
#   inflating: images/475_Pairings_55056.jpg
#   inflating: images/474_becloud_6520.jpg
#   inflating: images/473_oxblood_54848.jpg
#   inflating: images/472_Gmbh_32886.jpg
#   inflating: images/471_incompletely_38804.jpg
#   inflating: images/470_trampler_80118.jpg
#   inflating: images/469_Kestrels_42319.jpg
#   inflating: images/468_Lovers_45408.jpg
#   inflating: images/467_mischievous_48826.jpg
#   inflating: images/466_Newsweeklies_51513.jpg
#   inflating: images/465_TYPE_81485.jpg
#   inflating: images/464_Cowman_17659.jpg
#   inflating: images/463_LIONIZING_44691.jpg
#   inflating: images/462_Wilkes_86606.jpg
#   inflating: images/461_expropriating_27538.jpg
#   inflating: images/460_asleep_4274.jpg
#   inflating: images/459_DRIBBLE_23775.jpg
#  extracting: images/458_DEVILS_21283.jpg

# %%
IMAGES_PATH = "/content/images"

# %% [markdown]
# # Image Preprocessing

# %% [markdown]
# **Get Images Path**

# %%
def get_images_path(path):
    # Get all images file name 
    images_name = [image_name for image_name in os.listdir(path)]
    # Get full path with Python OS if the image labels is only lowercase alphabets
    return [os.path.join(path, image_name) for image_name in images_name if 
            image_name.split("_")[1].isalpha() and image_name.split("_")[1].islower()]

# %% [markdown]
# **Reading the Images**

# %%
def read_all_images(images_list):
    return [cv2.imread(image_path) for image_path in images_list]

# %% [markdown]
# **Deskew Images**

# %%
# Determine the score of a certain angle
# To decide and detect which angle the image is currently skewed in
def determine_score(arr, angle):
        data = inter.rotate(arr, angle, reshape=False, order=0)
        histogram = np.sum(data, axis=1)
        score = np.sum((histogram[1:] - histogram[:-1]) ** 2)
        return histogram, score

def deskew_images(all_images, delta=0.08, limit=12):
    rotated_images = []
    for image in all_images:
        # Find the threshold of the image after grayscaled
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1] 

        # Find the score of the image in a certain skew angle
        scores = []
        angles = np.arange(-limit, limit + delta, delta)
        for angle in angles:
            _, score = determine_score(thresh, angle)
            scores.append(score)
        # Find the best skew angle for the image 
        best_angle = angles[scores.index(max(scores))]

        # Rotate the image based on the best skew angle
        height, width = image.shape[:2]
        # Get the center of the image and generate rotation matrix from it
        center = (width // 2, height // 2)
        M = cv2.getRotationMatrix2D(center, best_angle, 1.0)
        # Rotate the image 
        rotated = cv2.warpAffine(image, M, (width, height), flags=cv2.INTER_LINEAR, borderMode=cv2.BORDER_REPLICATE)
        rotated_images.append(rotated)

    return rotated_images

# %% [markdown]
# **Resize Image to Uniform Size**

# %%
# Resize with linear interpolation to 100x40 dimension
def resize_images(all_images, height=40, width=100):
    resize_dim = (width, height)
    return [cv2.resize(image, resize_dim, interpolation=cv2.INTER_LINEAR) for image in all_images]

# %% [markdown]
# **Convert to Grayscale**

# %%
def convert_to_grayscale(all_images):
    return [cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) for image in all_images]

# %% [markdown]
# **Binarization**

# %%
def binarization(all_images):
    return [cv2.threshold(image, 180, 230, cv2.THRESH_BINARY, cv2.THRESH_OTSU + cv2.THRESH_BINARY)[1] for image in all_images]

# %% [markdown]
# **Image Dilation**

# %%
# Usually applied only to binarized image
def dilate_images(all_images, kernel_shape=(1, 1), num_iter=1):
    dilated_images = []
    # Dilate the images
    # Dilate basically tries to increase the size of an object in the image
    kernel = np.ones(kernel_shape, np.uint8)
    for image in all_images:
        dilated_images.append(cv2.dilate(image, kernel, iterations=num_iter))
    
    return dilated_images

# %% [markdown]
# **Images Erosion**

# %%
def erode_images(all_images, kernel_shape=(1, 1), num_iter=1):
    # Erode the images
    # Erode is the inverse of dilatation, where it sets the pixel value of the image to 0
    eroded_images = []
    for image in all_images:
        kernel = np.ones(kernel_shape, np.uint8)
        eroded_image = cv2.erode(image, kernel, iterations=num_iter)
        eroded_images.append(eroded_image)
    
    return eroded_images

# %% [markdown]
# **Image Smoothening**

# %%
# Combine both binary threshold and Otsu Threshold to smoothen the images
# Also use Gaussian Blur to soften the images
def smoothen_images(all_images):
    smooth_images = []
    for image in all_images:
        _, first_threshold = cv2.threshold(image, cv2.THRESH_BINARY, 200, 255, cv2.THRESH_BINARY)
        _, second_threshold = cv2.threshold(first_threshold, 180, 230, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
        blurred_image = cv2.GaussianBlur(second_threshold, (5, 5), 0)
        _, third_threshold = cv2.threshold(blurred_image, 180, 230, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
        smooth_images.append(third_threshold)
    return smooth_images

# %% [markdown]
# **Open-Closed Morphology Transformation**

# %%
def transform_morph(all_images):
    transformed_images = []
    for image in all_images:
        # # Apply Adaptive Threshold to the image
        filtered = cv2.threshold(image.astype(np.uint8), 180, 220, cv2.THRESH_OTSU, cv2.THRESH_BINARY)
        kernel = np.ones((1, 1), np.uint8)
        # Apply morphing to the image
        opening = cv2.morphologyEx(image, cv2.MORPH_OPEN, kernel)
        closing = cv2.morphologyEx(opening, cv2.MORPH_CLOSE, kernel)
        transformed_images.append(closing)
    return transformed_images

# %% [markdown]
# **Noise Removal**

# %%
def noise_removal(all_images):
    # Erode and dilate the image
    eroded_images = erode_images(all_images)
    dilated_images = dilate_images(eroded_images)
    # Get both transformed and smooth images from previous functions
    transformed_images = transform_morph(dilated_images)
    smooth_images = smoothen_images(dilated_images)

    # Zip both of the list and apply OR bitwise to the images in both side
    transformed_smooth_images = list(zip(smooth_images, transformed_images))
    return [cv2.bitwise_or(smooth_image, morph_image) for smooth_image, morph_image in transformed_smooth_images]

# %% [markdown]
# **Main Preprocessing Caller**

# %%
IMAGE_HEIGHT, IMAGE_WIDTH = (32, 128)

# %%
def preprocess_images(all_images):
    # Deskew images
    deskewed_images = deskew_images(all_images)
    # Resize the images
    resized_images = resize_images(deskewed_images, height=IMAGE_HEIGHT, width=IMAGE_WIDTH)
    # Convert the images into grayscaled images
    grayscaled_images = convert_to_grayscale(resized_images)
    # Binarize the images with Otsu Threshold
    # binarized_images = binarization(grayscaled_images)
    # Remove the noises in the images
    # final_images = smoothen_images(binarized_images)

    return grayscaled_images

# %% [markdown]
# Phew.. Man, that was one hell of a preprocessing. It's not perfect for some pictures, either words with characters stick together, word too thin, or other case where the image's resolution is bad. Even so, for good images and words, it is great enough to make the word look bolder and clearer than the provided image. Learnt many things from this process, and yep Computer Vision is hard, dude. :"D

# %% [markdown]
# Me from the future: turns out that I ended up not using all the preprocessing functions and only some basic techniques :)) Nevertheless, these functions might come in handy for future projects!

# %% [markdown]
# # Building the Dataset

# %% [markdown]
# **Extract Labels from Files' Names**

# %%
def extract_label(images_path):
    # Get the list of all images files in the path by stemming the full path
    return [(Path(label).stem).split("_")[1] for label in images_path]

# %% [markdown]
# **Building Dataset**

# %%
def build_data(path):
    # Get all images path
    images_list = get_images_path(path)
    # Get all images from files in the path
    raw_images = read_all_images(images_list)
    # Preprocess all images through the same pipeline
    final_images = preprocess_images(raw_images)
    # Extract all labels of the image from the path
    image_labels = extract_label(images_list)

    return np.array(final_images), np.array(image_labels)

# %% [markdown]
# **Convert the Label into Sequences**

# %%
ALL_CHARS = "abcdefghijklmnopqrstuvwxyz"
def generate_index_char():
    char_dict = {}
    for i in range(len(ALL_CHARS)):
        char_dict[ALL_CHARS[i]] = i
    
    return char_dict

# %%
def convert_to_sequence(labels):
    char_dict = generate_index_char()
    all_sequence = []
    
    for label in labels:
        sequence_labels = []
        for char in label:
            sequence_labels.append(char_dict.get(char))
        all_sequence.append(sequence_labels)
    
    return all_sequence

# %% [markdown]
# **Generate Timesteps for Bi-LSTM**

# %%
# Timesteps are the number of datapoints considered to predict a new data
# In this case, the number of maximum length of sequences in the input data
def generate_timesteps(data_size, steps):
    return np.array([steps] * data_size)

# %% [markdown]
# # Modelling

# %% [markdown]
# **Modelling the Attention Mechanism**

# %%
# https://stackoverflow.com/questions/62948332/how-to-add-attention-layer-to-a-bi-lstm
class Attention(Layer):
    # Constructor of the layer
    def __init__(self, return_sequences=True):
        self.return_sequences = return_sequences
        super(Attention, self).__init__()
    # Build the layer based on the Layer super class
    def build(self, input_shape):
        self.W=self.add_weight(name="att_weight", shape=(input_shape[-1], 1),
                               initializer="normal")
        self.b=self.add_weight(name="att_bias", shape=(input_shape[1], 1),
                               initializer="zeros")
        super(Attention, self).build(input_shape)
    # Caller
    def call(self, x):
        e = K.tanh(K.dot(x, self.W) + self.b)
        a = K.softmax(e, axis=1)
        output = x * a
        if self.return_sequences:
            return output
        return K.sum(output, axis=1)
    # Config
    def get_config(self):
        config = super().get_config().copy()
        config.update({
            'return_sequences': self.return_sequences 
        })
        return config

# %% [markdown]
# **Construct the CRNN Model with Connectionist Temporal Classification (CTC) Loss**

# %%
def construct_model(n_units=64, dropouts=0.2, MAX_LABEL_LEN=23):
    # Input tensor with image's dimensions, the last dimension is for grayscaled image
    input_layer = Input(shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 1))
    # First downsampling block, the Conv2D will use kernel size of (3, 3)
    downsampling_1 = Conv2D(n_units, (3, 3), activation="relu", padding="same")(input_layer)
    pooling_1 = MaxPool2D(pool_size=(2, 2), strides=2)(downsampling_1)
    # Second downsampling block, same as before
    downsampling_2 = Conv2D(n_units * 2, (3, 3), activation="relu", padding="same")(pooling_1)
    pooling_2 = MaxPool2D(pool_size=(2, 2), strides=2)(downsampling_2)
    # Third downsampling block, the Conv2D will use kernel size of (3, 3)
    downsampling_3_1 = Conv2D(n_units * 4, (3, 3), activation="relu", padding="same")(pooling_2)
    downsampling_3_2 = Conv2D(n_units * 4, (3, 3), activation="relu", padding="same")(downsampling_3_1)
    pooling_3 = MaxPool2D(pool_size=(2, 1))(downsampling_3_2)
    # Fourth downsampling + batch normalization to ease operations
    downsampling_4 = Conv2D(n_units * 4, (3, 3), activation="relu", padding="same")(pooling_3)
    normalize_1 = BatchNormalization()(downsampling_4)
    # Fifth downsampling, normalized + applied pooling
    downsampling_5 = Conv2D(n_units * 8, (3, 3), activation="relu", padding="same")(normalize_1)
    normalize_2 = BatchNormalization()(downsampling_5)
    pooling_4 = MaxPool2D(pool_size=(2, 1))(normalize_2)
    # Last CNN layer
    downsampling_6 = Conv2D(n_units * 8, (2, 2), activation="relu")(pooling_4)
    # Squeeze the output of CNN before
    lambda_squeeze = Lambda(lambda x: K.squeeze(x, 1))(downsampling_6)
    # Beginning the RNN layers
    bi_lstm_1 = Bidirectional(LSTM(n_units * 2, return_sequences=True, dropout=dropouts))(lambda_squeeze)
    bi_lstm_2 = Bidirectional(LSTM(n_units * 4, return_sequences=True, dropout=dropouts))(bi_lstm_1)
    bi_lstm_3 = Bidirectional(LSTM(n_units * 8, return_sequences=True, dropout=dropouts))(bi_lstm_2)
    # Attention layer for LSTM
    attention = Attention(return_sequences=True)(bi_lstm_3)
    # Dense output layer with Softmax activation function to find chars with highest probabilities
    # The units will be 27 (number of alphabets + 1 padding element)
    output_layer = Dense(27, activation="softmax")(attention)

    # Define the functional model to use in testing phase
    test_model = Model(input_layer, output_layer)

    # Define the CTC Loss function
    # Need 4 args: Predicted output, ground truth label, steps for both input and output
    def ctc_loss(args):
        y_pred, labels, input_length, label_length = args
        return K.ctc_batch_cost(labels, y_pred, input_length, label_length)

    # Define the training model additional inputs for CTC Loss
    labels = Input(shape=[MAX_LABEL_LEN], dtype="float32")
    input_length = Input(shape=[1], dtype="int64")    
    label_length = Input(shape=[1], dtype="int64")

    # Define the loss output with Lambda function for CTC Loss
    loss_function = Lambda(ctc_loss, output_shape=(1, ), name="ctc")([output_layer, labels, input_length, label_length])

    # Create the model used in training session
    training_model = Model(inputs=[input_layer, labels, input_length, label_length], outputs=loss_function)

    return training_model, test_model

# %% [markdown]
# **Train and Fit the Model**

# %%
def train_and_fit(epochs=50, batch_size=256):
    # Initialize model saving checkpoint, callbacks list, and file path to save only the best parameters
    # The metric to determine which model is the best is the Validation Loss score 
    MODEL_SAVE_FILE_PATH = "Recon.hdf5"
    checkpoint = ModelCheckpoint(filepath=MODEL_SAVE_FILE_PATH, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
    callbacks_list = [checkpoint]

    training_model.fit(
    x=[training_images, training_sequences, training_timesteps, training_label_length],
    y=np.zeros(len(training_images)),
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(
        [validation_images, validation_sequences, validation_timesteps, validation_label_length],
        [np.zeros(len(validation_images))]),
    verbose=1, callbacks=callbacks_list)

# %% [markdown]
# # Metrics

# %% [markdown]
# **Predict All Validation Data**

# %%
def get_predicted_label(prediction):
    full_text = []
    for pred in prediction:
        if int(pred) != -1:
            full_text.append(ALL_CHARS[int(pred)])
    return "".join(full_text)

# %%
def get_all_predicted_labels():
    # Make and decode the predictions
    predictions = test_model.predict(validation_images)
    decoded_preds = K.get_value(K.ctc_decode(predictions, 
                                        input_length=np.ones(predictions.shape[0]) * predictions.shape[1],
                                        greedy=True)[0][0])
    
    # Store all predicted labels
    all_predictions = []
    for prediction in decoded_preds:
        all_predictions.append(get_predicted_label(prediction))
    
    return np.array(all_predictions)

# %% [markdown]
# **Calculating Accuracy Metrics**

# %%
def calculate_accuracy(validation_label, all_predictions):
    # Calculate the accuracy
    accuracy = (all_predictions == validation_label).mean()

    return accuracy

# %% [markdown]
# **Calculating Mean Leveinshtein Distance Metrics**

# %%
def calculate_mean_levenshtein_distance(labels, predictions):
    # Recursively calculate Levenshtein
    # The manual recursion stucks for words with duplicate characters sticking together
    def levenshtein_score(label, predicted):
        # if not label:
        #     return len(predicted)
        # if not predicted:
        #     return len(label)
        # if label[-1] == predicted[-1]:
        #     cost = 0
        # else:
        #     cost = 1
        
        # return min([levenshtein_score(label[:-1], predicted) + 1,
        #             levenshtein_score(label, predicted[:-1]) + 1, 
        #             levenshtein_score(label[:-1], predicted[:-1]) + cost])
        return edit_distance(label, predicted)
    assert(len(labels) == len(predictions))

    # Calculate total distances for all strings in the labels and predictions
    total = 0
    for label, prediction in list(zip(labels, predictions)):
        total += levenshtein_score(label, prediction)
    
    # Return the mean distance
    return total / len(labels)

# %% [markdown]
# **Main Metrics Caller**

# %%
def output_metrics(validation_labels):
    # Get all predicted labels
    predictions = get_all_predicted_labels()
    # Accuracy
    print(f"Accuracy of the Model: {calculate_accuracy(validation_labels, predictions)}")
    # Mean Levenshtein Distance
    print(f"Mean Levenshtein Distance: {calculate_mean_levenshtein_distance(validation_labels, predictions)}")

# %% [markdown]
# # Main Pipeline

# %% [markdown]
# **Read All Images Data and Labels**

# %%
# Get all images data and labels
all_images_data, all_images_labels = build_data(IMAGES_PATH)

# %%
MAX_LABEL_LEN = max([len(label) for label in all_images_labels])

# %% [markdown]
# **Create Training Data**

# %%
# Create the training data with first 14000 images
n = 14000
training_images = all_images_data[:n]
training_labels = all_images_labels[:n]
training_label_length = np.array([len(text) for text in training_labels])

# %%
# Normalize the image, convert label to sequences and generate timesteps
training_images = training_images / 255.
training_sequences = convert_to_sequence(training_labels)
training_timesteps = generate_timesteps(len(training_images), MAX_LABEL_LEN)

# %%
# Pad the sequences with post-sequence method
# The value will be the number of unique chars, that is 26, since 0 is already used
training_sequences = pad_sequences(training_sequences, maxlen=MAX_LABEL_LEN, padding='post', value = 26)

# %% [markdown]
# **Create Validation**

# %%
# Create the validation data with remaining images
validation_images = all_images_data[n:]
validation_labels = all_images_labels[n:]
validation_label_length = np.array([len(text) for text in validation_labels])

# %%
# Normalize the image, convert label to sequences and generate timesteps
validation_images = validation_images / 255.
validation_sequences = convert_to_sequence(validation_labels)
validation_timesteps = generate_timesteps(len(validation_images), MAX_LABEL_LEN)

# %%
# Pad the sequences with post-sequence method
# The value will be the number of unique chars, that is 26, since 0 is already used
validation_sequences = pad_sequences(validation_sequences, maxlen=MAX_LABEL_LEN, padding='post', value = 26)

# %% [markdown]
# **Initiate the Model**

# %%
training_model, test_model = construct_model(MAX_LABEL_LEN=MAX_LABEL_LEN)

# %% [markdown]
# **Check the Models Summary**

# %%
training_model.summary()
# Out:
# Model: "model_13"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_26 (InputLayer)           [(None, 32, 128, 1)] 0
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 32, 128, 64)  640         input_26[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_28 (MaxPooling2D) (None, 16, 64, 64)   0           conv2d_49[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 16, 64, 128)  73856       max_pooling2d_28[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_29 (MaxPooling2D) (None, 8, 32, 128)   0           conv2d_50[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 8, 32, 256)   295168      max_pooling2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 8, 32, 256)   590080      conv2d_51[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_30 (MaxPooling2D) (None, 4, 32, 256)   0           conv2d_52[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 4, 32, 256)   590080      max_pooling2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 4, 32, 256)   1024        conv2d_53[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 4, 32, 512)   1180160     batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 4, 32, 512)   2048        conv2d_54[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_31 (MaxPooling2D) (None, 2, 32, 512)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 1, 31, 512)   1049088     max_pooling2d_31[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 31, 512)      0           conv2d_55[0][0]
# __________________________________________________________________________________________________
# bidirectional_18 (Bidirectional (None, 31, 256)      656384      lambda_7[0][0]
# __________________________________________________________________________________________________
# bidirectional_19 (Bidirectional (None, 31, 512)      1050624     bidirectional_18[0][0]
# __________________________________________________________________________________________________
# bidirectional_20 (Bidirectional (None, 31, 1024)     4198400     bidirectional_19[0][0]
# __________________________________________________________________________________________________
# attention_8 (Attention)         (None, 31, 1024)     1055        bidirectional_20[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 31, 27)       27675       attention_8[0][0]
# __________________________________________________________________________________________________
# input_27 (InputLayer)           [(None, 23)]         0
# __________________________________________________________________________________________________
# input_28 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_29 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# ctc (Lambda)                    (None, 1)            0           dense_6[0][0]
#                                                                  input_27[0][0]
#                                                                  input_28[0][0]
#                                                                  input_29[0][0]
# ==================================================================================================
# Total params: 9,716,282
# Trainable params: 9,714,746
# Non-trainable params: 1,536
# __________________________________________________________________________________________________

# %% [markdown]
# **Compile the Model**

# %%
training_model.compile(loss={"ctc": lambda y, y_pred: y_pred}, optimizer="adam")

# %% [markdown]
# **Train, Fit, and Save the Model**

# %%
train_and_fit()
# Out:
# Epoch 1/50
# 55/55 [==============================] - 21s 374ms/step - loss: 1.6363 - val_loss: 5.7858
#
# Epoch 00001: val_loss improved from inf to 5.78577, saving model to Recon.hdf5
# Epoch 2/50
# 55/55 [==============================] - 21s 376ms/step - loss: 1.4943 - val_loss: 5.6147
#
# Epoch 00002: val_loss improved from 5.78577 to 5.61473, saving model to Recon.hdf5
# Epoch 3/50
# 55/55 [==============================] - 21s 382ms/step - loss: 1.6476 - val_loss: 5.5168
#
# Epoch 00003: val_loss improved from 5.61473 to 5.51683, saving model to Recon.hdf5
# Epoch 4/50
# 55/55 [==============================] - 20s 373ms/step - loss: 1.2331 - val_loss: 5.7148
#
# Epoch 00004: val_loss did not improve from 5.51683
# Epoch 5/50
# 55/55 [==============================] - 21s 375ms/step - loss: 0.9542 - val_loss: 5.7908
#
# Epoch 00005: val_loss did not improve from 5.51683
# Epoch 6/50
# 55/55 [==============================] - 21s 380ms/step - loss: 0.8423 - val_loss: 5.9196
#
# Epoch 00006: val_loss did not improve from 5.51683
# Epoch 7/50
# 55/55 [==============================] - 21s 375ms/step - loss: 0.7437 - val_loss: 5.9785
#
# Epoch 00007: val_loss did not improve from 5.51683
# Epoch 8/50
# 55/55 [==============================] - 21s 375ms/step - loss: 0.6564 - val_loss: 5.9489
#
# Epoch 00008: val_loss did not improve from 5.51683
# Epoch 9/50
# 55/55 [==============================] - 21s 379ms/step - loss: 0.5544 - val_loss: 5.8836
#
# Epoch 00009: val_loss did not improve from 5.51683
# Epoch 10/50
# 55/55 [==============================] - 21s 378ms/step - loss: 0.4613 - val_loss: 6.0486
#
# Epoch 00010: val_loss did not improve from 5.51683
# Epoch 11/50
# 55/55 [==============================] - 24s 444ms/step - loss: 0.4280 - val_loss: 6.0815
#
# Epoch 00011: val_loss did not improve from 5.51683
# Epoch 12/50
# 55/55 [==============================] - 23s 428ms/step - loss: 0.3828 - val_loss: 5.9838
#
# Epoch 00012: val_loss did not improve from 5.51683
# Epoch 13/50
# 55/55 [==============================] - 21s 376ms/step - loss: 0.3509 - val_loss: 6.1971
#
# Epoch 00013: val_loss did not improve from 5.51683
# Epoch 14/50
# 55/55 [==============================] - 21s 381ms/step - loss: 0.3869 - val_loss: 6.2517
#
# Epoch 00014: val_loss did not improve from 5.51683
# Epoch 15/50
# 55/55 [==============================] - 23s 425ms/step - loss: 0.4202 - val_loss: 6.4118
#
# Epoch 00015: val_loss did not improve from 5.51683
# Epoch 16/50
# 55/55 [==============================] - 20s 373ms/step - loss: 0.3175 - val_loss: 6.2198
#
# Epoch 00016: val_loss did not improve from 5.51683
# Epoch 17/50
# 55/55 [==============================] - 21s 384ms/step - loss: 0.2943 - val_loss: 6.3453
#
# Epoch 00017: val_loss did not improve from 5.51683
# Epoch 18/50
# 55/55 [==============================] - 20s 371ms/step - loss: 0.2663 - val_loss: 6.2187
#
# Epoch 00018: val_loss did not improve from 5.51683
# Epoch 19/50
# 55/55 [==============================] - 20s 371ms/step - loss: 0.2160 - val_loss: 6.5368
#
# Epoch 00019: val_loss did not improve from 5.51683
# Epoch 20/50
# 55/55 [==============================] - 21s 379ms/step - loss: 0.1908 - val_loss: 6.3720
#
# Epoch 00020: val_loss did not improve from 5.51683
# Epoch 21/50
# 55/55 [==============================] - 21s 376ms/step - loss: 0.1838 - val_loss: 6.6761
#
# Epoch 00021: val_loss did not improve from 5.51683
# Epoch 22/50
# 55/55 [==============================] - 20s 370ms/step - loss: 0.1905 - val_loss: 6.6476
#
# Epoch 00022: val_loss did not improve from 5.51683
# Epoch 23/50
# 55/55 [==============================] - 21s 378ms/step - loss: 0.1865 - val_loss: 6.5353
#
# Epoch 00023: val_loss did not improve from 5.51683
# Epoch 24/50
# 55/55 [==============================] - 21s 379ms/step - loss: 0.1906 - val_loss: 6.5423
#
# Epoch 00024: val_loss did not improve from 5.51683
# Epoch 25/50
# 55/55 [==============================] - 21s 380ms/step - loss: 0.1631 - val_loss: 6.6718
#
# Epoch 00025: val_loss did not improve from 5.51683
# Epoch 26/50
# 55/55 [==============================] - 20s 373ms/step - loss: 0.1653 - val_loss: 6.7760
#
# Epoch 00026: val_loss did not improve from 5.51683
# Epoch 27/50
# 55/55 [==============================] - 20s 369ms/step - loss: 0.1972 - val_loss: 6.7844
#
# Epoch 00027: val_loss did not improve from 5.51683
# Epoch 28/50
# 55/55 [==============================] - 21s 380ms/step - loss: 0.1578 - val_loss: 6.7243
#
# Epoch 00028: val_loss did not improve from 5.51683
# Epoch 29/50
# 55/55 [==============================] - 20s 372ms/step - loss: 0.1618 - val_loss: 6.8035
#
# Epoch 00029: val_loss did not improve from 5.51683
# Epoch 30/50
# 55/55 [==============================] - 21s 375ms/step - loss: 0.1464 - val_loss: 6.5664
#
# Epoch 00030: val_loss did not improve from 5.51683
# Epoch 31/50
# 55/55 [==============================] - 21s 379ms/step - loss: 0.1615 - val_loss: 7.0047
#
# Epoch 00031: val_loss did not improve from 5.51683
# Epoch 32/50
# 55/55 [==============================] - 21s 379ms/step - loss: 0.1803 - val_loss: 6.8779
#
# Epoch 00032: val_loss did not improve from 5.51683
# Epoch 33/50
# 55/55 [==============================] - 20s 372ms/step - loss: 0.1879 - val_loss: 6.7885
#
# Epoch 00033: val_loss did not improve from 5.51683
# Epoch 34/50
# 55/55 [==============================] - 21s 378ms/step - loss: 0.1787 - val_loss: 6.6924
#
# Epoch 00034: val_loss did not improve from 5.51683
# Epoch 35/50
# 55/55 [==============================] - 21s 377ms/step - loss: 0.1344 - val_loss: 6.8387
#
# Epoch 00035: val_loss did not improve from 5.51683
# Epoch 36/50
# 55/55 [==============================] - 20s 371ms/step - loss: 0.1187 - val_loss: 6.9871
#
# Epoch 00036: val_loss did not improve from 5.51683
# Epoch 37/50
# 55/55 [==============================] - 21s 374ms/step - loss: 0.1457 - val_loss: 7.0536
#
# Epoch 00037: val_loss did not improve from 5.51683
# Epoch 38/50
# 55/55 [==============================] - 21s 378ms/step - loss: 0.1934 - val_loss: 6.9521
#
# Epoch 00038: val_loss did not improve from 5.51683
# Epoch 39/50
# 55/55 [==============================] - 20s 372ms/step - loss: 0.1475 - val_loss: 6.9208
#
# Epoch 00039: val_loss did not improve from 5.51683
# Epoch 40/50
# 55/55 [==============================] - 20s 371ms/step - loss: 0.1392 - val_loss: 7.0004
#
# Epoch 00040: val_loss did not improve from 5.51683
# Epoch 41/50
# 55/55 [==============================] - 21s 380ms/step - loss: 0.1459 - val_loss: 6.6863
#
# Epoch 00041: val_loss did not improve from 5.51683
# Epoch 42/50
# 55/55 [==============================] - 21s 377ms/step - loss: 0.1361 - val_loss: 7.0072
#
# Epoch 00042: val_loss did not improve from 5.51683
# Epoch 43/50
# 55/55 [==============================] - 21s 377ms/step - loss: 0.1372 - val_loss: 6.7327
#
# Epoch 00043: val_loss did not improve from 5.51683
# Epoch 44/50
# 55/55 [==============================] - 20s 372ms/step - loss: 0.1147 - val_loss: 6.9322
#
# Epoch 00044: val_loss did not improve from 5.51683
# Epoch 45/50
# 55/55 [==============================] - 21s 375ms/step - loss: 0.0947 - val_loss: 6.8168
#
# Epoch 00045: val_loss did not improve from 5.51683
# Epoch 46/50
# 55/55 [==============================] - 21s 381ms/step - loss: 0.0788 - val_loss: 6.9656
#
# Epoch 00046: val_loss did not improve from 5.51683
# Epoch 47/50
# 55/55 [==============================] - 21s 374ms/step - loss: 0.0918 - val_loss: 7.0162
#
# Epoch 00047: val_loss did not improve from 5.51683
# Epoch 48/50
# 55/55 [==============================] - 21s 375ms/step - loss: 0.0979 - val_loss: 7.2909
#
# Epoch 00048: val_loss did not improve from 5.51683
# Epoch 49/50
# 55/55 [==============================] - 21s 381ms/step - loss: 0.1458 - val_loss: 7.0619
#
# Epoch 00049: val_loss did not improve from 5.51683
# Epoch 50/50
# 55/55 [==============================] - 21s 374ms/step - loss: 0.1440 - val_loss: 6.9433
#
# Epoch 00050: val_loss did not improve from 5.51683

# %% [markdown]
# # Inference and Testing

# %% [markdown]
# **Some Inferences**

# %%
# Load the trained model weights from the saved file
test_model.load_weights("Recon.hdf5")
test_model.summary()
# Out:
# Model: "model_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_26 (InputLayer)        [(None, 32, 128, 1)]      0
# _________________________________________________________________
# conv2d_49 (Conv2D)           (None, 32, 128, 64)       640
# _________________________________________________________________
# max_pooling2d_28 (MaxPooling (None, 16, 64, 64)        0
# _________________________________________________________________
# conv2d_50 (Conv2D)           (None, 16, 64, 128)       73856
# _________________________________________________________________
# max_pooling2d_29 (MaxPooling (None, 8, 32, 128)        0
# _________________________________________________________________
# conv2d_51 (Conv2D)           (None, 8, 32, 256)        295168
# _________________________________________________________________
# conv2d_52 (Conv2D)           (None, 8, 32, 256)        590080
# _________________________________________________________________
# max_pooling2d_30 (MaxPooling (None, 4, 32, 256)        0
# _________________________________________________________________
# conv2d_53 (Conv2D)           (None, 4, 32, 256)        590080
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 4, 32, 256)        1024
# _________________________________________________________________
# conv2d_54 (Conv2D)           (None, 4, 32, 512)        1180160
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 4, 32, 512)        2048
# _________________________________________________________________
# max_pooling2d_31 (MaxPooling (None, 2, 32, 512)        0
# _________________________________________________________________
# conv2d_55 (Conv2D)           (None, 1, 31, 512)        1049088
# _________________________________________________________________
# lambda_7 (Lambda)            (None, 31, 512)           0
# _________________________________________________________________
# bidirectional_18 (Bidirectio (None, 31, 256)           656384
# _________________________________________________________________
# bidirectional_19 (Bidirectio (None, 31, 512)           1050624
# _________________________________________________________________
# bidirectional_20 (Bidirectio (None, 31, 1024)          4198400
# _________________________________________________________________
# attention_8 (Attention)      (None, 31, 1024)          1055
# _________________________________________________________________
# dense_6 (Dense)              (None, 31, 27)            27675
# =================================================================
# Total params: 9,716,282
# Trainable params: 9,714,746
# Non-trainable params: 1,536
# _________________________________________________________________

# %%
# Randomize ten indices to index the image
random_indices = np.random.randint(len(validation_images), size=10)
# Get the prediction from the model of random indices images
predictions = test_model.predict(validation_images[random_indices])
# Decode the prediction output with CTC Loss Decoder
decoded_preds = K.get_value(K.ctc_decode(predictions, 
                                        input_length=np.ones(predictions.shape[0]) * predictions.shape[1],
                                        greedy=True)[0][0])

# %%
# Output the prediction results
curr_index = 0
for prediction in decoded_preds:
    predicted_text = get_predicted_label(prediction)
    print(f"True Label: {validation_labels[random_indices[curr_index]]}")
    print(f"Predicted Label: {predicted_text}\n")
    curr_index += 1
# Out:
# True Label: fanged
# Predicted Label: fanged
#
# True Label: subjoins
# Predicted Label: guliains
#
# True Label: hydrocephalus
# Predicted Label: huratohes
#
# True Label: guantanamo
# Predicted Label: guantonamo
#
# True Label: travelogue
# Predicted Label: travelocues
#
# True Label: hogarth
# Predicted Label: hogarth
#
# True Label: enliven
# Predicted Label: enliven
#
# True Label: hoer
# Predicted Label: hoer
#
# True Label: torrider
# Predicted Label: torrider
#
# True Label: mingo
# Predicted Label: mingo

# %% [markdown]
# **Output the Metrics**

# %%
output_metrics(validation_labels)
# Out:
# Accuracy of the Model: 0.5229598530569405
# Mean Levenshtein Distance: 1.2377328785095776

# %% [markdown]
# # Takeaways

# %% [markdown]
# I actually used up all my GPU limits in Colab and cannot try more experiments to do the training (I actually also forgot that there are limits to its usage bruh) `:')`. The model is not actually that bad, in my opinion.
#
# Anyway, the model is not actually that bad, in my opinion. The average edit distance needed for the model's validation data is ~1 character with the accuracy of slightly more than 50%.
#
# This means that most inaccuracies made by the model is actually only because one different character, and that is actually great. Nonetheless, the validation loss is still high (~5). I was actually preparing to feed more data into the model and the limit notification pops up right away `T_T`.
